# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import re
import os
import csv
from khaiii import KhaiiiApi

# %%
df = pd.read_csv("refined_data_pre.tsv", delimiter='\t', names=['tag', 'sentence'])
df
# Out:
#           tag                                           sentence
# 0       문제 정의  재난관리체계의 개선(일원화)방법으로는 여러 가지가 있을 수 있겠으나 여기서는 재난관...
# 1       문제 정의  이 연구는 재난관리에 관여하는 조직 및 부처들 간의 얼마만큼 재난관리와 관련한 공조...
# 2      대상 데이터  본 연구의 사용된 표본의 특성은 Table 5와 같다. 설문지 응답자들의 근무처를 ...
# 3      대상 데이터  우리나라에서 재난관리 활동에 영향을 주는 외적요인을 다중응답 분석을 이용해서 살펴보...
# 4      대상 데이터  연구자는 국가통합재난관리행정체계에 대한 연구+목적을 달성하기 위하여 소방방재청(기획...
# ...       ...                                                ...
# 63388   기술 정의  스마트시티는 일반적으로 물리적 도시시설이 사물인터넷 등 ICT 기술과 접목되어 효율...
# 63389   제안 방법  본 연구에서는 스마트시티에 대한 국내외 현황을 조사하고, 리빙랩 방식으로 시민들의 ...
# 63390  대상 데이터  국내외 스마트시티 현황 및 추진사례에서 발현된 핵심전략과 특화프로그램을 종합하여 생...
# 63391   성능/효과  이에 따른 주요 실행계획으로는, ①도시 스마트시스템을 구축하여 건강하고 살기 좋은 ...
# 63392   성능/효과  건강하고 지속가능한 커뮤니티조성, 인종 및 공간 형평성을 통한 다양한 커뮤니티와 지...
#
# [63393 rows x 2 columns]

# %%
Text_train = df['sentence']

# %%
Text_train
# Out:
# 0        재난관리체계의 개선(일원화)방법으로는 여러 가지가 있을 수 있겠으나 여기서는 재난관...
# 1        이 연구는 재난관리에 관여하는 조직 및 부처들 간의 얼마만큼 재난관리와 관련한 공조...
# 2        본 연구의 사용된 표본의 특성은 Table 5와 같다. 설문지 응답자들의 근무처를 ...
# 3        우리나라에서 재난관리 활동에 영향을 주는 외적요인을 다중응답 분석을 이용해서 살펴보...
# 4        연구자는 국가통합재난관리행정체계에 대한 연구+목적을 달성하기 위하여 소방방재청(기획...
#                                ...
# 63388    스마트시티는 일반적으로 물리적 도시시설이 사물인터넷 등 ICT 기술과 접목되어 효율...
# 63389    본 연구에서는 스마트시티에 대한 국내외 현황을 조사하고, 리빙랩 방식으로 시민들의 ...
# 63390    국내외 스마트시티 현황 및 추진사례에서 발현된 핵심전략과 특화프로그램을 종합하여 생...
# 63391    이에 따른 주요 실행계획으로는, ①도시 스마트시스템을 구축하여 건강하고 살기 좋은 ...
# 63392    건강하고 지속가능한 커뮤니티조성, 인종 및 공간 형평성을 통한 다양한 커뮤니티와 지...
# Name: sentence, Length: 63393, dtype: object

# %%
api = KhaiiiApi()

def pos_text(Text_train):
    corpus = []
    for sent in Text_train:
        pos_tagged = ''
        for word in api.analyze(sent):
            for morph in word.morphs:
                pos_tagged += morph.lex + ' '
        corpus.append(pos_tagged.strip())
    return corpus

Text_train = pos_text(Text_train)

# %%
Text_train
# Out:
# ['재난 관리 체계 의 개선 ( 일원 화 ) 방법 으로 는 여러 가지 가 있 을 수 있 겠 으나 여기 서 는 재난 관리 분야 에서 사실 상 중추 적 역할 을 담당 ( 특히 각종 재난 현장 대응 의 주체역 ) 하 고 있 는 소방 조직 을 중심 으로 일원 화 하 는 방안 을 검토 하 고자 하 ㄴ다 .',
#  '이 연구 는 재난 관리 에 관여 하 는 조직 및 부처 들 간 의 얼마 만큼 재난 관리 와 관련 하 ㄴ 공조 체계 , 또는 협조 체계 를 이루어지 고 있 는지 를 파악 하 는데 목적 이 있 다 .',
#  '본 연구 의 사용 되 ㄴ 표본 의 특성 은 Table 5 와 같 다 . 설문지 응답자 들 의 근무처 를 확인 하 면 소방방재청 ( 기획 조정관실 , 예방 안전국 , 소방 정책국 , 방재 관리국 , 재난 상황실 , 중앙 119 구조대 , 중앙 소 방학 교 ) 에 200 부 를 배포 하 여 167 명 응답 하 여 83 . 5 % 회수 되 었 으며 , 지방 자치 단체 ( 서울특별 시 , 광역 시 , 도 , 시 및 자치구 ) 에 200 부 를 배포 하 여 136 명 으로 68 . 0 % 회수 되 었 다 .',
#  '우리나라 에서 재난 관리 활동 에 영향 을 주 는 외 적 요인 을 다중 응 답 분석 을 이용 하 여서 살펴보 면 소방방재청 은 자연 적 요인 ( 95 . 8 % ) ,; 물리 적 요인 ( 64 . 1 % ) ,; 사회 문화 적 요인 ( 47 . 3 % ) ,; 인간 의 행위 요인 ( 37 . 7 % ) 순 이 고 , 지방 자치 단체 는 자연 적 요인 ( 91 . 9 % ) ,; 사회 문화 적 요인 ( 54 . 4 % ) ,; 물리 적 요인 ( 49 . 3 % ) ,; 인간 의 행위 요인 ( 48 . 5 % ) 순 으로 나타나 았 다 .',
#  '연구자 는 국가 통합 재난관리 행정 체계 에 대하 ㄴ 연구 + 목적 을 달성 하 기 위하 여 소방방재청 ( 기획 조정관실 , 예방 안전국 , 소방 정책국 , 방재 관리국 , 재난 상황실 , 중앙 119 구조대 , 중앙 소 방학 교 ) 과 지방 자치 단체 ( 서울특별시 , 광역시 , 도 , 시 및 자치구 ) 를 대상 으로 2009 년 8 월 1 일 부터 9 월 10 일 까지 설문 조사 조사 를 받 았 으며 , 회수 되 ㄴ 303 개 설문 중 소속 기관 별 로 소방방재청 167 개 , 지방 자치 단체 136 개 의 설문 을 회수 하 여 설문 결과 를 토대 로 조사 결과 에 대하 ㄴ 분석 을 하 였 다 .',
#  '설문 분석 은 사회 과학 분석 에 주로 사용 되 는 통계 프로그램 이 ㄴ SPSS ( 15 . 0 ) 를 활용 하 여 분석 하 였 다',
#  '연구 의 목적 을 달성 하 기 위하 여 사용 되 ㄴ 분석 방법 으로 빈도 분석 , 카 이 제곱검정 , 독립 표본 T 검정 을 실시 하 였 다',
#  '이 연구 설문 결과 에서 재난 관리 단계 중 혼선 이 가장 많 은 단계 가 대응 단계 로 나타나 ㄴ 것 으로 보 아 현 재난 관리 기관 들 의 재난 발생 시 대응 이 미비 하 ㅁ 을 의미 하 ㄴ다 .',
#  '이 연구 의 설문 조사 결과 에서 나타나 ㄴ 바 와 같이 현재 통합 재난 관리 체계 가 보다 효율 적 이 고 실용 적 이 ㄴ 국가 재난 관리 체계 정비 가 필요 하 며 , 이 에 언제 , 어디 서 , 어떤 규모 로 발생 하 ㄹ지 모르 는 국가 재난 에 대하 ㄴ 효율 적 이 ㄴ 관리 체계 를 구축 하 ㅁ 으로써 국민 의 생명 과 안전 에 대하 ㄴ 대비 를 강화 하 여야 하 ㄴ다 .',
#  '미래 에 대하 ㄴ 긍정 적 이 ㄴ 측면 이 있 기 때문 에 앞 에서 제시 하 ㄴ 통합 과 재난 관련법 의 제시 는 꼭 필요 하 다 .',
#  '상기 연구 와 더불 어 보 ㄴ 연구 에서 는 화재 피난 영향 평가 를 통하 여 화재 위험 및 피난 안전 분석 기법 의 수준 을 제고 시키 고 , 향후 시행 되 ㄹ 화재 피난 영향 평가제 의 기준 마련 과 원활 하 ㄴ 제도 운영 에 도움 을 주 고자 하 ㄴ다 .',
#  "본 연구 에서 는 화재 및 피난 안전 성 확보 를 위하 ㄴ 성능 위주 설계 와 관련 하 여 대구 D 대학 기숙사 건물 ( 이하 ' 기숙사 ' 로 표기 ) 에 대하 ㄴ 화재 시뮬레이션 을 통하 여 아트리움 에 설치 되 ㄴ 방화 셔터 와 배연구 의 아트리움 제연 효과 에 대하 ㄴ 성능 확인 과 더불 어 화재 피난 영향 평가 를 통하 여 화재 위험 및 피난 안전 에 대하 여 분석 하 고자 하 ㄴ다 .",
#  '열 과 연기 의 자연 배연 이 란 화재실 내 창문 또는 설계 되 ㄴ 배연구 를 통하 여 고온 의 연기 부력 과 팽창 에 의하 ㄴ 외부 로 의 고온 연기 의 제거 와 더불 어 외부 로부터 신선 하 ㄴ 공기 가 유입 되 도록 하 는 것 을 말 하 ㄴ다 .',
#  '본 연구 에서 는 대구 D 대학 기숙사 건물 에 대하 여 2 MW , 5 MW 화재크기 와 방화 셔터 의 미설치 및 작동 경우 의 4 가지 화재시나리오 를 구성 하 고 , FDS ( ver . 5 . 5 . 0 ) 와 Pathfinder 2009 프로그램 을 사용 하 여 화재 피난 시뮬레이션 을 수행 하 였 다 .',
#  '본 연구 의 화재 피난 영향 평가 대상 건물 이 ㄴ 기숙사 는 식당 , 세탁실 , 휴게실 , 기계실 , 사감실 , 학생 방 과 더불 어 건물 중앙 에 아트리움 공간 으로 구성 되 ㄴ 지하 1 층 지상 8 층 규모 의 건물 이 다 .',
#  '본 연구 의 화재 피난 영향 평가 대상 건물 이 ㄴ 기숙사 는 지하 1 층 에 는 식당 , 세탁실 , 휴게실 , 기계실 과 지상 1 층 에 는 로비 , 사감실 과 남학생 방 , 2 층 과 3 층 에 는 남학생 방 , 4 층 에서 7 층 에 는 여학생 방 , 그리고 외국인 , 교수 방 , 8 층 에 는 옥상 계단실 등 을 포함 하 ㄴ 지하 1 층 지상 8 층 규모 이 며 , 건물 공간 중앙 에 는 아 트리움 으로 건축 되 ㄴ 건물 이 다 .',
#  '( 1 ) 방화셔터 작동 경우 , 아트리움 주위 로 의 연기 전파 가 차단 되 ㅁ 으로써 화재 위험 방지 에 크 ㄴ 효과 가 있 었 다 .',
#  '( 2 ) 방화셔터 미설 치 , 화재크기 가 2 MW 이 ㄴ 경우 , 온도 에 의하 ㄴ 화재 위험 은 없 었 고 가 시거리 에 의하 ㄴ 화재 위험 도달시간 은 t = 80 초 이 다 .',
#  '( 3 ) 지상 1 층 주출 입구 까지 전체 피난자 의 순수 피난 이동 시간 은 136 초 이 며 , 전체 피난자 의 1 층 건물 주 출입구 까지 피난 대피 하 ㄹ 경우 , 계단실 까지 의 피난 시간 에 비하 여 약 110 초 이상 증가 하 게 되 ㄴ다 .',
#  '그러나 상부 배연구 를 통하 ㄴ 배연량 이 불 충분 하 여 방화 셔터 의 유무 에 관계없이 아트리움 내 의 연기 층 은 바닥 으로부터 약 2 m 지점 까지 하강 하 여 한계 높 이 이하 가 되 었 다 .',
#  '본 연구 의 화재 위험 분석 결과 , 방화셔터 가 작동 하 는 경우 연기 의 온도 가 낮 아 화재 위험 은 거의 없 으나 , 일부 공간 에서 일시 적 으로 화재 안전 기준값 보다 낮 은 가시거리 로 인하 여 피난 에 다소 어려움 이 예상 되 ㄴ다 .',
#  '피난자 의 더 안전 하 ㄴ 피난 을 위하 여 추가 적 이 ㄴ 보완 조치 가 필요 하 다고 사료 되 ㄴ다 .',
#  '그리고 피난자 에 대하 ㄴ 계단실 피난 여유 시간 은 약 5 초 이내 로 매우 작 게 나타나 았 다 .',
#  '화재크기 가 5 MW 의 경우 , 건물 중 · 상부 층 에 대하 여 화재 위험 도달시간 은 온도 와 가 시 거리 각각 약 85 초 와 36 초 로써 온도 보다 는 가시거리 에 의하 ㄴ 화재 위험 이 더 크 게 나타나 았 다 .',
#  '본 논문 에서 는 한국 , 미국 , 일본 , 프랑스 , 영국 , 독일 , 등 이 참여 하 여 연구 중 이 ㄴ 국제 공 동 연구 OECD / NEA PRISME Project 를 통하 여 수행 되 ㄴ 화재실증 실험 결과 를 가지 고 화재 분석 모델 중 의 하나 이 ㄴ FDS ( Fire Dynamics Simulator version 5 . 3 ) 를 예측 능력 및 입력 변수 의 민감 도 측면 에서 검증 하 고자 하 ㄴ다 .',
#  '화재 분석 모델 은 질량 , 운동량 및 에너지 보존 법칙 을 기반 으로 화재 로 인하 ㄴ 구조물 , 계통 및 기기 에 대하 ㄴ 손상 등 을 수학 적 으로 예측 하 는 방법 이 다 .',
#  '화재실증 실험 설비 , 계측기 , 실험 조건 과 FDS 의 경계 조건 및 주요 입력 요소 를 전반부 에 기술 하 고 , 실험 결과 를 바탕 으로 모델 의 예측능력 및 중요 입력 요소 이 ㄴ 열방 출률 및 환기량 에 대하 ㄴ 민감도 를 분석 하 ㄴ다 .',
#  '본 연구 에 사용 되 ㄴ 화재실증 실험 은 두께 0 . 3 m 의 강화 콘크리트 벽 으로 구성 되 ㄴ 두 개 의 격실 에서 수행 하 ㄴ다 .',
#  '본 연구 에서 는 화염 및 고온 연기 층 으로 인하 ㄴ 주위 영향 을 분석 하 기 위하 여서 온도 , 농도 , 및 열유 속 을 측정 하 여 해석 하 였 다 .',
#  '화재 진행 에 따르 ㄴ 가연 성 액체 TPH 의 열방출률 은 화재실증 실험 을 통하 여 얻 은 질량손실 률 에 단위질량당 연소열 ∆ Hc = 47 , 500 kJ / kg 10 , 11 ) 을 곱 하 여 계산 하 며 , 이렇 게 계산 되 ㄴ 열방출률 을 Figure 4 에 표시 하 였 다 .',
#  '계산 되 ㄴ 열방출률 을 FDS 에 입력 하 기 위하 여 열방출률 추세 와 근사 하 ㄴ 곡선 을 추정 하 여 Figure 4 에 표시 하 였 으며 , 추정 되 ㄴ 곡선 을 바탕 으로 시간 대별 질량 손실 률 과 열방출률 을 Table 7 에 나타내 었 다 .',
#  '본 연구 에서 FDS 의 화재 설정 은 열방 출률 HRR 의 입력 을 통하 여 수행 되 ㄴ다 .',
#  '또한 유입 및 유출 공기 의 온도 는 25 oC , 상대 습도 는 40 % 로 각각 설정 하 였 다 .',
#  '연료 팬 의 하부 에 는 연소 로 인하 ㄴ 질량손실 률 을 측정 하 기 위하 ㄴ 질량 측정기 가 설치 되 어 화재 진행 동안 연료 의 질량변화 를 측정 하 ㄴ다 .',
#  '연소생성물 이 ㄴ CO 와 Soot 의 생성 률 은 실험 조건 과 같이 각각 0 . 013 g / g 와 0 . 056 g / g 으로 설정 하 였 고 , 개구부 를 통하 ㄴ 공기 유입 및 유출 은 ± 0 . 158 m 3 / sec 으로 실험 조건 과 동 일 하 게 설정 하 여 , 격실 의 외부 로부터 유입 및 유출 되 는 흐름 은 없 는 것 으로 경계 조건 을 설정 하 였 다 .',
#  '가연 성 액체 연료 이 ㄴ TPH 와 구조물 의 초기 온도 는 25 o C , 상대습 도 40 % 로 설정 하 였 으며 , 구조물 을 구성 하 고 있 는 강화 콘크리트 에 대하 ㄴ 경계 조건 은 Table 6 과 같이 설정 하 였 다 .',
#  '화재 는 액체 상태 의 TPH 16 . 266 kg 을 원형 연료 팬 에 담 아 놓 고 점화 장치 를 이용 및 착화 하 여 모든 연료 가 소모 되 ㄹ 때 까지 진행 되 ㄴ다 .',
#  '국제 공동 연구 OECD / NEA PRISME Project 의 참여 를 통하 여 수행 되 ㄴ 화재실증 실험 결과 가 비교 분석 에 이용 되 었 다 .',
#  '열유 속 의 경우 , 열방출률 의 미소 증가 혹은 감소 에 따르 아 최대 8 % 의 열유속 증가 및 감소 영향 을 주 는 것 으로 관측 되 었 으나 , 환기량 변화 에 따르 ㄴ 열유속 영향 은 없 었 다 .',
#  '또한 환기 가 제한 되 고 외부 로부터 밀폐 되 ㄴ 두 개 의 격실 에서 열방 출률 및 환기 / 배기량 은 화재 측면 에서 중요 하 ㄴ 요소 이 기 때문 에 열방 출률 및 환기 / 배기량 의 미세 변화 ( ± 10 % ) 에 대하 ㄴ 온도 , 열유속 , 연소생성물 및 산소 농도 의 민감 도 분석 결과 를 나타내 었 다 .',
#  '또한 , 산소 농도 는 상층부 및 하층부 에서 열방 출률 및 환기량 의 미소변화 에 민감 하 게 반응 하 며 , 특히 상층부 의 경우 에 는 열방출률 미소 변화 가 환기량 미소변화 보다 더 민감 하 게 영향 받 음 을 검증 하 였 다 .',
#  '화재실증 실험 과 시뮬레이션 결과 를 바탕 으로 모델 의 예측 능력 을 분석 하 였 다 .',
#  '결론 적 으로 한 격실 이 5 m × 6 m × 4 m 크기 이 ㄴ 이중격실 수조 화 재 에 있 어서 FDS 의 온도 , 열유 속 및 농도 예측 능력 은 실험 대비 약 10 ~ 20 % 의 오차 를 나타내 었 으며 , FDS 에서 환기량 미소변화 는 온도 및 열유 속 의 민감도 에 별다르 ㄴ 영향 을 주 지 못하 지만 , 열방 출률 미소 변화 에 온도 및 열유 속 은 상당히 민감 하 ㅁ 을 확인 하 였 다 .',
#  '입력 변수 에 대하 ㄴ 민감도 는 열방출률 미소 변화 의 경우 온도 는 5 ~ 10 % 증감 을 보이 었 으나 , 환기량 미소변화 의 경우 온도 변화 는 거의 나타나 지 않 았 다 .',
#  '이중격실 공간 내 에서 가연 성 액체 의 수조 화 재 에 대하 ㄴ FDS 의 예측 능력 은 실험 값 대비 온도 의 경우 약 20 % 오차 범위 를 나타내 었 으며 , 열유 속 은 약 10 % 오차 범위 , 농도 는 약 15 % 의 오차 범위 를 나타내 었 다 .',
#  '산소 농도 의 경우 환기량 또는 열방출률 미소 변화 에 영향 을 받 았 으며 , 상층부 에서 는 열방출률 미소변화 의 영향 이 하층부 에서 는 환기량 미소변화 의 영향 이 민감 하 게 작용 하 였 다 .',
#  '본 논문 에서 는 소방 현장 활동 과 관계 를 분석 하 여 현장 대응 에 적절 하 ㄴ 법 을 제정 하 여야 하 ㄴ다 .',
#  '따라서 보 ㄴ 연구 의 목적 은 소방 공무원 들 이 현장 활동 중 석면 함유 비산먼지 로 위협 되 고 있 는 현상 을 조사 하 고 발생 원인 을 찾 아 현장 활동 대응 기준 을 마련 하 여 석면 노출 을 효과 적 으로 예방 하 는데 있 다 .',
#  '석면 으로 인하 여 발생 하 는 석면 폐암 , 악성중피종 과 같 은 질병 으로부터 소방 공무원 을 보호 하 고 , 해 마다 증가 추세 를 보이 고 있 는 직업병 을 토대 로 공무 상 재해 의 기준 , 기존 의 잘못 되 ㄴ 관행 , 절차 , 불 합리 하 ㄴ 여건 들 을 변화 시키 ㅁ 으로써 조직 운영 의 최적 화 와 안전 하 고 쾌적 하 ㄴ 근무 여건 을 통하 여 소방 공무원 들 이 소방 활동 에서 치명 적 이 ㄴ 위해 요소 를 사전 에 제거 하 는데 보 ㄴ 연구 의 배경 이 다 .',
#  '첫째 , 재난 · 재해 현장 활동 이 가 ㄹ수록 증가 하 고 있 는 상황 에서 붕괴 현장 및 석면 가루 비산 시 착용 하 여야 하 ㄹ 보호 장비 , 소방 활동 시 석면가루 가 우리 소방 활동 에 얼마나 많이 노출 되 고 있 는지 분석 하 ㄴ다 .',
#  '둘째 , 석면 과 관련 되 ㄴ 소방 공무원 의 이해 정도 를 조사 하 기 위하 여 석면 의 유해 성 , 석면 의 체내 침입 경 로 , 잠복기 , 사용 하 여야 하 는 보호구 , 피부 를 노출 시키 면 안 되 는 이유 , 석면 제거 현장 에서 금지 되 는 활동 등 에 대하 여 설문 조사 , 관찰 , 심층 면접 등 여러 방법 을 통하 여 진단 분석 하 고 , 더불 어 소방 활동 의 문제점 을 파악 하 ㄴ다 .',
#  '셋째 , 소방 활동 시 개인 보호 장비 와 현장 활동 진압 장비 등 석면 으로부터 위협 되 는 각종 요소 를 사전 제거 하 ㄹ 수 있 도록 하 여 안전 하 ㄴ 근무 환경 을 만들 기 위하 ㄴ 구체 적 이 ㄴ 실천 방안 을 마련 하 여 소방 공무원 의 건강 증진 에 기여코 자 하 ㅁ 이 다 .',
#  '본 연구 는 현재 전국 소방 조직 을 대상 으로 하 고 , 거시 적 이 ㄴ 측면 에서 는 소방 조직 전체 를 , 미시 적 이 ㄴ 측면 에서 는 일선 소방서 와 119 안전센터 에서 소방 활동 을 하 고 있 는 진압 대원 을 중심 으로 하 였 다 .',
#  '앞서 언급 하 ㄴ 바 와 같이 보 ㄴ 조사 는 석면 분진 에 대하 ㄴ 소방 공무원 의 대응 활동 강화 에 대하 여 보다 정확 하 ㄴ 인식도 와 유해 성 에 대하 ㄴ 실태 파악 을 위하 여 2008 . 5 . 29 ~ 6 . 7 일 까지 현재 전라북도 소방 공무원 1 , 450 명 을 대상 으로 실시 하 ㄴ 결과 약 10 % 이 ㄴ 143 명 의 답변 자료 를 권역 별 로 표본 을 추출 하 였 다 .',
#  '전라북도 10 개 소방서 를 권역 별 로 구분 하 여 전자 문서 를 통하 여 설문지 를 배부 하 고 143 부 의 설문지 를 회수 하 여 분석 에 활용 하 였 다 .',
#  '조직 활동 진단 을 위하 여 설문 조사 를 실시 하 고 소방 현장 활동 의 특성 을 분석 하 였 다 .',
#  "전라북도 소방 공무원 143 명 을 대상 으로 실시 하 ㄴ ' 석면 이 인체 에 얼마나 유해 적 요소 이 ㄴ가 ' 에 대하 ㄴ 문항 에서 석면 에 대하 여 ' 잘 알 지 못하 ㄴ다 ! ' 46 . 8 % ( 67 명 ) , ' 전혀 알 지 못하 ㄴ다 ' 17 . 5 % ( 5 명 ) 로 응답자 의 64 . 3 % ( 응답자 의 2 / 3 ) 가 석면 에 대하 ㄴ 유해 성 을 인식 하 지 못하 고 있 는 것 으로 나타나 았 다 .",
#  '둘째 , 석면 해체 · 제거 시 사전 조사 와 소방 활동 기준 등 직무 별 석면 분진 노출 실태 를 조사 하 여 소 방 활동 에서 석면 노출 을 최소 화 하 는 법령 을 제정 하 고 , 직무 로 인하 여 발생 되 는 질환 을 예방 하 고 조기 에 발견 하 ㄹ 수 있 도록 특수 건강 검 진 항목 에 석면노출 근로자 와 동일 하 ㄴ 내용 을 추가 하 ㅁ 으로써 항목 자체 를 일원 화 시키 며 , 퇴직 공무원 의 건강피 하 여 실태 조사 를 통하 ㄴ 지속 적 이 ㄴ 소방 공무원 감시 체계 구축 하 여야 하 ㄴ다 .',
#  '첫째 , 잔해물 해체 · 제거 시 대상물 별 세부 계획 을 수립 하 고 석면 이 공기 중 에 방출 되 지 못하 도록 제거 대상물 에 집중 분무 주수 하 고 피부 와 시력 을 보호 하 ㄹ 수 있 게 소방 대원 에게 적절 하 ㄴ 호흡 보호구 가 제공 되 어야 하 며 , 석면 노출 이 우려 되 는 현장 에 소방 활동 대응 매뉴얼 과 장소 별 해체 · 제거 표준 절차 를 마련 하 여 석면 유해 성 에 대하 ㄴ 현장 대응 능력 을 강화 하 여야 하 겠 으며 , 소방 학교 등 교육 전문 기관 에서 는 체계 적 이 ㄴ 프로그램 개발 과 석면 물질 전문가 육성 , 일선 현장 활동 대원 에 대하 여 는 석면 물질 의 위험 성 및 현장 활동 에 대하 ㄴ 직무 교육 을 강화 하 여야 하 ㄴ다 .',
#  '셋째 , 소방 방재청 및 소방 안전본부별 석면 종합 대책 T / F 팀 을 구성 하 여 재난 별 소방 활동 을 강구 하 며 , 지급 장비 활용 대응 능력 에 대하 ㄴ 향상 방안 을 마련 하 여 현장 활동 대응 능력 과 전문 성 을 강화 하 여야 하 ㄴ다 .',
#  '상대 적 으로 건물 붕괴 와 화재 진압 등 으로 발생 되 는 석면 분진 노출 정도 에 대하 ㄴ 인식 부족 으로 1 / 4 정도 만 소방 공무원 이 석면 에 노출 되 ㄴ다고 생각 하 는 것 으로 나타나 았 다 .',
#  "' 석면노출 현장 에서 가장 필요 하 ㄴ 것 이 무엇 이 ㄴ가 ? ' 이 라는 질문 에서 는 석면 분진 으로부터 시력 및 호흡기 계통 을 보호 하 기 위하 ㄴ 보호 장구 의 강화 35 . 6 % ( 51 명 ) , 교육 과정 신설 28 % ( 40 명 ) , 분석 · 철거 장비 도입 22 . 4 % ( 32 명 ) 로 방진마스크 , 보호 장갑 , 보호 의 등 석면 분진 보호 장비 가 활동 시 가장 필요 하 ㄴ 것 으로 나타나 았 다 .",
#  '석면 노출 기준 에 의하 ㄴ 보호 장비 착용 으로 철저 하 ㄴ 소방 활동 을 강화 하 ㅁ 은 물론 소방 활동 상 유해성인자 의 심각 성 을 인식 하 고 질환 피해 보상 에 대하 ㄴ 법 적 제도 를 마련 하 여 아직 까지 인정 되 고 있 지 않 은 질병 에 대하 ㄴ 공무 상 재해인정 을 통하 ㄴ 제도 적 미비 점 을 보완 하 며 , 석면 에 대하 ㄴ 위험 성 뿐만 아니 라 화재열 , 붕괴 , 추락 , 독 성 가스 , 검딩 ( soot 등 ) 등 으로부터 의 보호 에 대하 ㄴ 제도 적 이 ㄴ 측면 의 개선 과 보완 으로 소방 공무원 의 사기 진작 및 근무 여건 개선 으로 대국민 서비스 향상 을 기대 하 ㄹ 수 있 을 것 이 다 .',
#  '본 연구 에서 는 20 층 규모 의 모델 건축물 을 대상 으로 화재 안전 기준 과 엔지니어링 설계 방안 을 바탕 으로 급기 가 압 제 연시스템 을 설계 하 였 고 , 네트워크 모델 의 수치 해석 기법 을 사용 하 여 급기 가 압 제 연시스템 의 가동 으로 건축물 내 에 형성 되 는 압력장 을 분석 하 ㄴ 결과 다음 과 같 은 결론 을 얻 었 다 .',
#  '한편 수직 풍도 에서 의 풍속 이 20 m / s 가 되 도록 풍도면적 을 산정 하 고 , 풍도 의 거칠 기 는 아연도강판 에 해당 하 는 0 . 15 mm 로 설정 하 였 다 .',
#  '급기 가 압 제 연시스템 의 두 번 째 운전 조건 은 부속실 의 출입문 이 개방 되 는 경우 로서 보 ㄴ 연구 에서 는 모델 건축물 의 10 층 의 부속실 출입문 이 개방 되 었 을 경우 에 대하 여 해석 을 수행 하 였 다 .',
#  '한편 현 단계 의 연구 에서 는 건축물 내부 와 외부 의 온도차 는 고려 하 지 않 기 때문 에 건축물 내부 와 외부 의 온도 는 동 일 하 게 가정 하 였 다 .',
#  '급기 가 압 제 연시스템 에서 부속실 과 거실사이 에 차압 을 기준치 로 유지 하 는데 핵심 적 이 ㄴ 역할 을 하 는 설비 가 자동 차압 · 과 압 조절 형 급기댐퍼 이 다 .',
#  '급기 가 압 제 연시스템 은 외기 를 건축물 내 제연 구역 에 급기 하 여 제연 구역 과 화재 발생 구역 간 에 압력차 를 발생 시키 는 것 으로서 , 이 에 대하 ㄴ 효과 적 이 ㄴ 해석 을 위하 여서 는 송풍 시스템 , 압력 제어 장치 , 수직 풍도 구성 , 피난문댐퍼 개폐 조건 , 틈새누기특성 등 건축물내 압력장 형성 에 영향 을 미치 는 설비 와 건축 적 요인 들 을 모두 고려 하 여야 하 ㄴ다 .',
#  '본 연구 에서 는 20 층 규모 의 모델 건축물 을 대상 으로 NFSC 501 A 기준 과 엔지니어링 설계 방안 을 바탕 으로 급기 가 압 제 연시스템 을 설계 하 였 으며 , 네트워크 모델 의 수치 해석 기법 을 사용 하 여 급기 가 압 제 연시스템 에 의하 여 형성 되 는 건축물 나 의 압력장 을 분석 하 였 다 .',
#  '본 연구 에서 는 각 경우 에 대하 여 앞장 의 모델 건축물 을 대상 으로 네트워크 모델 프로그램 으로 운영 상황 을 해석 하 였 다 .',
#  '연구 대상 이 ㄴ 모델 건축물 은 Figure 1 과 같이 지상 20 층 의 건물 로서 해석 범위 는 특별 피난 계단 1 식 에 대하 여 부속실 , 계단실 , 급기 가 압 시스템 을 포함 하 도록 하 였 다 .',
#  '본 연구 에서 는 각 층 에 설치 되 어 있 는 자동 차압 · 과 압 조절 형 급기댐퍼 를 Duct Terminal 로 모델링 하 이 었 으며 기본 적 으로 송풍기 에서 공급 되 는 총풍량 에서 각 층 으로 동일 하 ㄴ 풍량 이 공급 되 도록 각 층 의 Duct Terminal 의 동적 손실 계수 를 조절 하 였 다 .',
#  '본 연구 에서 는 급기 가 압 제 연시스템 에 의하 ㄴ 송풍 작용 과 이 에 따르 ㄴ 건축물 나 의 각 구획 에서 의 압력 형성 을 분석 하 기 위하 여서 네트워크 모델 에 기반 하 ㄴ CONTAMW 2 . 4 프로그램 을 사용 하 였 다 .',
#  '10 층 의 부속실 출입문 이 개방 되 면 10 층 출입문 을 통하 여 방연 풍속 으로 설계 되 ㄴ 풍량 보다 많 은 풍량 이 거실 로 유출 되 며 , 이 로 인하 여서 13 층 이하 의 층 에서 는 부속실 로 공급 되 는 풍량 이 누설량 에 미치 지 못하 여 부속실 과 거실 가 ㄴ 차압 이 설계 차압 보다 낮 게 형성 되 ㄴ다 .',
#  '모든 층 의 부속실 내 출입문 이 닫히 어 있 는 상태 에서 누설량 만큼 만 송풍기 를 통하 여 급기 하 ㄹ 경우 에 는 부속실 과 거실 간 차압 이 설계 차압 이 ㄴ 50 Pa 로 유지 되 나 , 누설량 과 보충량 을 합하 ㄴ 풍량 을 급기 하 ㄹ 경우 에 는 부속실 과 거실 가 ㄴ 차압 이 설계 차압 보다 상당히 높 게 형성 되 ㄴ다 .',
#  '현재 의 급기 가 압 제 연시스템 의 설계 방안 과 같이 한 개 의 급기 풍도 를 통하 여 누설량 과 보충량 이 동시 에 공급 되 ㄹ 경우 에 는 부속실 과 거실 간 에 형성 되 는 차압 이 설계 기준 에 미달 하 거나 과압 이 되 ㄹ 가능 성 이 매우 높 아 지 어서 급기 가 압 제 연시스템 의 설치 목적 을 달성 하 지 못하 ㄹ 수 있 으므로 이 에 대하 ㄴ 효과 적 이 ㄴ 개선 방안 이 필요 하 다 .',
#  '우리나라 에서 는 관계 기관 의 허가 를 받 는 경우 , 실제 총기 를 사용 하 는 실내 사격장 영업 이 가능 하 며 , 전국 적 으로 15 개 의 사격장 이 영업 중 에 있 는 실정 으로 실내 사격장 에서 화재 사고 및 인명 피해 에 대하 ㄴ 잠재 적 위험 성 을 지니 고 있 다 .',
#  '본 연구 에서 는 부산 실내 사격장 화재사고 로 인하 ㄴ 인명 피해 발생 을 계기 로 리볼버 권총 사용 에 따르 ㄴ 화약 잔사 발생량 을 실제 검출 하 였 다 .',
#  '따라서 보 ㄴ 연구 에서 는 실내 사격장 에서 사용 되 ㄴ 권총 과 유사 하 ㄴ 제품 을 이용 하 여 격발 과정 에서 발생 되 는 화약 잔사 를 2 가지 조건 에 따르 아 측정 하 였 다 .',
#  '또한 권총 발사 과정 에서 분출 되 ㄴ 화약 잔사 를 수거 하 여 충격감 도 , 마찰감 도 , 정전기감 도 및 발화점 등 의 발화 특성 을 측정 하 였 으며 , 비교 평가 를 위하 여 권총 에 사용 되 는 사용전 의 화약 을 대상 으로 화약 잔사 와 동일 하 ㄴ 시험 을 수행 하 였 다 .',
#  '부산 실내 사격장 에서 사용 되 ㄴ 총기 는 미국 Smith & Wesson 사 의 모델 686 , 구경 0 . 357 인치 7 연발 리 볼버 권 총 이 다 .',
#  '따라서 보 ㄴ 연구 에서 도 화약 잔사 에 대하 ㄴ 발화 특성 을 평가 하 기 위하 여 낙추 시험 , 마찰 시험 , 정전기인가시험 및 발화점 시험 을 실시 하 였 으며 , 비교 평가 를 위하 여 Figure 6 에 나타내 ㄴ 바 와 같이 사용전 의 화약 에 대하 여 동일 하 ㄴ 특성 시험 을 수행 하 였 다 .',
#  '또한 검출 되 ㄴ 화약 잔사 및 사용전 화약 에 대하 ㄴ 화재 및 폭발 위험 성 평가 를 위하 여 충격감 도 , 마찰감 도 , 정전기감 도 및 발화점 온도 를 측정 하 였 으며 , 다음 과 같 은 결론 을 얻 었 다 .',
#  '또한 사고 현장 이 ㄴ 실내 사격장 의 조건 을 모의 하 기 위하 여 Figure 4 와 같이 사대 를 개방 하 ㄴ 상태 에서 사대 주변 에 백지 를 펼치 어 놓 고 , 구경 0 . 38 인치 권총 을 100 발 발사 하 는 경우 , 사대 정면 및 측면 에 떨어지 는 화약 잔사 의 양 을 검출 하 였 다 .',
#  '측정 에 사용 되 ㄴ 총기 는 구경 0 . 38 인치 권총 및 구경 9 mm 리 볼 버 권총 으로 Figure 2 와 같이 사대 측 을 밀폐 하 ㄴ 상태 에서 각각 5 발 을 발사 하 고 , 밀폐 공간 내 에 남기 어 지 ㄴ 화약 잔사 의 양 을 측정 하 였 다 .',
#  '첫째 , 화약 잔사 의 실측 결과 , 권총 격발 과정 에서 발생 되 는 화약 잔사 는 탄환 에 사용 되 는 화약 의 10 % 정도 가 발생 되 는 것 으로 평가 되 었 으며 , 사대 를 개방 시키 ㄴ 조건 에서 는 총구 기준 으로 사대 의 직하단 및 사대 와 의 거리 150 cm 에서 240 cm 사이 에서 집중 적 으로 화약 잔사 가 분포 하 는 특성 을 나타내 었 다 .',
#  '실험 결과 , 충격 감 도 및 마찰 감도 는 화약 잔사 가 사용전 의 화약 에 비하 여 다소 높 게 측정 되 었 고 , 발화점 시험 에서 는 화약 잔사 가 비교 대상 이 ㄴ 사용전 의 화약 에 비하 여 낮 은 온도 에서 발화 되 는 특성 을 나타내 었 다 .',
#  '둘째 , 발화 특성 시험 에서 충격 감 도 및 마찰 감도 는 사용전 의 화약 에 비하 여 상대 적 으로 높 게 측정 되 었 으며 , 발화점 은 낮 아 지 는 특성 을 나타내 었 다 .',
#  '셋째 , 정전기 감돌 는 18 kV 범위 까지 기폭 되 지 않 는 특성 을 나타내 었 으며 , 정전기 에 대하 여서 는 비교 적 안정 되 ㄴ 특성 을 가지 는 것 으로 판단 되 ㄴ다 .',
#  '특히 , 실내 사격장 내부 에서 화약 잔사 가 다량 존재 하 는 경우 , 동 화약 잔사 를 매개 로 급속 하 ㄴ 연소 확대 가 가능 하 ㄹ 것 으로 판단 되 ㄴ다 .',
#  '이러 하 ㄴ 실험 결과 는 실내 사격장 및 권총 화약 제조 과정 에서 발생 되 ㄹ 수 있 는 화재 사고 에 대하 ㄴ 현장 조사 기법 제공 및 화약 과 화약 잔사 에 대하 ㄴ 화재 위험 성 연구 의 기초 자료 로 활용 가능 하 ㄹ 것 으로 기대 하 ㄴ다 .',
#  '따라서 보 ㄴ 연구 를 통하 여 산불 에서 의 주요 연소 물질 이 ㄴ 지표 층 연료 에 대하 여 실험 적 접근 방법 을 통하 여 뒷불 의 연소 특성 을 규명 하 고자 하 ㄴ다 .',
#  '본 연구 에서 는 일반 적 이 ㄴ 산불 에서 의 낙엽 층 을 대상 으로 뒷불 에 대하 ㄴ 연소 특성 에 대하 여 살펴보 고자 하 ㄴ다 .',
#  '훈소 는 뒷불 의 초기 단계 로 화염 으로 발생 되 는 중간 단계 역할 을 하 게 되 ㄴ다 .',
#  '각 연료 층 의 깊이 는 채취 장소 의 조건 과 유사 하 ㄴ 조건 으로 소나무 , 굴참나무 낙엽 에 대하 여 L 층 깊이 는 5 c m , 10 cm 로 하 여 실험 을 실시 하 였 다 .',
#  '산림내 낙엽 층 ( L 층 ) 과 낙엽 분해 층 ( F 층 ) , 부식 층 ( H 층 ) 을 채취 , 원통 형 바스켓 에 채취 밀도 와 동일 하 ㄴ 밀도 이 ㄴ L 층 ( 28 . 3 kg / m 3 ) 및 F , H 층 ( 283 . 1 kg / m 3 ) 을 채우 어 넣 고 연소 특성 실험 을 하 였 다 .',
#  '각 연료 층별 온도 변화 측정 은 L 층 표면 에 불꽃 점화 후 각층 의 경계면 의 온도 가 100 oC 이하 로 감소 되 ㄹ 때 까지 측정 하 였 다 .',
#  '이때 각 낙엽 층별 함수 율 은 L 층 15 ~ 20 % , F - H 층 20 ~ 60 % 이 며 , 연소 특성 ( 수직온도 분포 , 연소 시간 , 전파 속 도 , 지속 시간 ) 을 측정 하 였 다 .',
#  '채집 되 ㄴ 낙엽 은 동일 하 ㄴ 함수율 조건 을 맞추 기 위하 여 45 o C 의 건조기 에서 168 시간 동안 건조 시키 ㄴ 후 사용 하 였 으며 , 실험 시료 는 실험 준비 중 불가피 하 게 대기 중 에 노출 되 며 , 이때 시료 의 함수율 이 변화 되 어 , 15 ~ 20 % 범위 의 시료 를 실험 하 였 다 .',
#  '낙엽 분해 층 ( F 층 ) , 부식 층 ( H 층 ) 의 시료 는 매 실험 시 마다 인근 야산 에서 시료 를 채집 하 여 Moisture analyzer ( AND , MX - 50 ) 를 이용 하 여 함수율 을 측정 실험 하 였 다 .',
#  '뒷불 재 발 화 실험 에 사용 되 ㄴ 낙엽 시료 는 침엽 수종 이 ㄴ 소나무 ( Pinus densiflora : P . D . ) 낙엽 과 활엽 수종 이 ㄴ 굴참 나무 ( Quercus variabilis : Q . V . ) 낙엽 을 자연 상태 에서 채집 하 였 다 .',
#  '데이터 수집 은 DAQ ( Agilent , 34970 A ) 를 이용 하 여 1 초 단위 로 측정 분석 하 였 다 .',
#  '열 전대 ( K - type ) 는 총 8 개 를 이용 하 였 으며 , 산림 내 낙엽 층 ( L 층 ) 과 낙엽 분해 층 ( F , H 층 ) 의 경계면 의 위치 에 있 는 열전대 T 1 ~ T 3 를 2 . 5 cm 간격 으로 하 였 으며 , T 4 ~ T 8 은 5 cm 간격 으로 배치 하 여 실험 하 였 다 .',
#  'Figure 4 는 수종 별 분해 층 중심부 가 발화 하 기 시작 하 여 , 탄화 하 기 시작 하 는 온도 보다 낮 은 약 70 oC 까지 의 하강 시간 을 지속 시간 으로 간주 하 였 다 .',
#  '활엽수 의 경우 10 cm 두께 에서 함수 율 20 % 의 경우 지속 시간 이 약 15 시간 정도 이 었 으며 , 함수 율 30 % 의 경우 지속 시간 이 약 18 시간 정도 로 측정 되 었 다 .',
#  'Figure 6 은 함수율 에 따르 ㄴ 지속 시간 으로 분해 층 이 5 cm 이 ㄴ 경우 함수율 이 35 % 이 면서 약 11 시간 지속 되 며 , 10 cm 이 ㄴ 경우 함수율 이 35 % 이 면서 약 23 시간 정도 연소 가 지속 되 었 다 .',
#  'L - F 층 의 경계 층 이 ㄴ T 3 지점 에서 최고 440 oC 까지 측정 되 었 고 약 120 분 동안 100 oC 이상 의 온도 를 유지 하 였 으며 , F - H 층 의 경계 층 이 ㄴ T 2 지점 에서 최고 394 oC 까지 측정 되 었 고 약 130 분 동안 100 oC 이상 의 온도 를 유지 하 였 다 .',
#  '함수율 과 전파 속도 는 반 비례 경향 을 보이 ㄴ다',
#  '함수율 이 35 % 이 면서 분해 층 이 5 cm 이 ㄴ 경우 약 11 시간 지속 되 며 , 10 cm 이 ㄴ 경우 약 22 시간 연소 시간 이 관찰 되 었 다 .',
#  '뒷불 전이 가 일어나 ㄹ 경우 유기물 층 의 온도 는 350 oC 이상 상승 하 며 , 함수율 별 낙엽 층 ( L 층 ) 에서 의 온도 변화 는 평균 450 ~ 500 oC 로 측정 되 었 다 .',
#  '결과 적 으로 약 60 분 경 에 F - H 층 으로 열 이 전이 되 어 뒷불 재 발 화 가 발생 하 ㄴ 것 으로 사료 되 ㄴ다 .',
#  'F 층 과 H 층 으로 의 뒷불 전 이 임계 발화 습도 는 35 ~ 44 % 사이 에 위치 하 며 , 전 이 발생 시 유기물 층 의 온도 는 약 350 oC 이상 으로 상승 하 였 다 .',
#  '점화 후 L - F 층 의 경계 층 에서 열 이 전이 가 안 되 었 으며 , 결과 적 으로 뒷불 재 발 화 가 발생 하 지 않 은 것 으로 사료 되 ㄴ다 .',
#  'Figure 3 은 소나무 L 층 이 10 cm 이 ㄴ 경우 로 L 층 중앙 T 4 지점 에서 약 600 oC 까지 측정 되 었 고 , 약 25 분 동안 100 oC 이상 의 온도 를 유지 하 였 다 .',
#  'L - F 층 의 경계 층 이 ㄴ T 3 지점 에서 최고 65 oC 까지 측정 되 었 다',
#  '여기 서 점화 후 약 40 분 경 과 지점 에서 H layer 층 의 T 2 지점 의 온도 가 급격히 증가 하 기 시작 하 여 , 약 80 분 경 에 약 400 oC 부근 까지 온도 가 상승 하 였 다 .',
#  '결론 적 으로 같 은 함수율 이 ㄴ 경우 지속 시간 은 두께 에 비례 하 며 , 같 은 두께 이 ㄹ 경우 함수율 과 지속 시간 은 비례 하 ㄴ다',
#  '분해 층 두께 가 2 배 증가 시 최고온 도 도달 시간 및 지속 시간 은 약 2 배 증가 되 는 것 으로 측정 되 었 다',
#  '분해 층 두께 가 5 cm 이 ㄴ 경우 침엽 수종 과 활엽 수종 의 지속 시간 은 약 10 시간 정도 이 며 , 10 cm 이 ㄴ 경우 지속 시간 은 약 21 시 간 으로 측정 되 었 다 .',
#  '낙엽 층 ( L 층 ) 중앙 T 4 지점 ( 10 cm ) 에서 약 600 oC 까지 측정 되 었 으나 , T 3 ( L 층 과 F 층 경계면 ) 가 발화점 이상 으로 올라가 지 않 고 소염 되 어 재 발 화 가능 성 이 희박 하 다',
#  '분해 층 두께 별 지속 시간 은 분해 층 두께 가 2 배 증가 시 최고온 도 도달 시간 및 지속 시간 도 비례 하 여 약 2 배 증가 되 ㄴ다 .',
#  'Figure 2 는 굴참나무 L 층 이 10 cm 이 ㄴ 경우 로 L 층 의 T 4 지점 에서 최고 510 oC 까지 측정 되 었 고 약 60 분 동안 100 oC 이상 의 온도 를 유지 하 였 다 .',
#  '낙엽 층 ( L 층 ) 중앙 T 4 지점 ( 10 cm ) 에서 약 510 oC 까지 측정 되 었 으며 , T 3 ( L 층 과 F 층 경계면 ) 가 약 400 oC 부근 에서 T 2 의 온도 가 급격히 증가 하 기 시작 하 여 , 약 60 분 경 에 낙엽 층 에서 F - H 층 으로 온도 가 전이 되 어 재 발 화 가 발생 하 ㄹ 가능 성 이 높 다',
#  'Figure 7 은 침엽 수종 과 활엽 수종 의 함수 율 에 따르 ㄴ 낙엽 과 분해 층 의 경계면 에서 중심 까지 의 전파 속도 로 시료 의 함수 율 과 전파 속도 는 반 비례 경향 을 보이 ㄴ다',
#  '유기물층 의 뒷불 전 이 임계 습도 가 35 ~ 44 % 사이 에 존재 하 며 , 그 이상 의 습도 에서 는 전이 가 일어나 지 않 았 다 .',
#  '낙엽 층 ( L 층 ) 에서 의 온도 변화 는 평균 450 ~ 500 oC 로 측정 되 었 으며 , 급작스 럽 ㄴ 외부 환경 변화 ( 돌풍 , 표면 탄화 물질 의 제거 ) 가 발생 하 지 않 는 경우 약 40 % 의 함수율 을 임계뒷불 재 발 화 습도 이 라고 하 ㄹ 수 있 다 .',
#  '뒷불 재 발 화 특성 및 감시 등 관리기법 이 과학 적 으로 구명 되 어 있 지 않 으며 , 뒷불 재 발 화 특성 및 단계 별 진화 관리 기술 이 미흡 하 고 산불 현장 에서 뒷불정리 를 위하 ㄴ 작업 및 관리 기준 등 이 없 어 뒷불 재 발 화 에 의하 ㄴ 대 형 산불 로 의 확산 이 빈번히 발생 되 고 있 어 , 이 에 관하 ㄴ 연구 가 필요 하 다 .',
#  '본 논문 은 인위 적 으로 누전 회로 를 형성 하 여 누전 개소 에 목분진 과 빗물 , 목탄 의 2 종 류 의 시료 를 입력 하 여 누전 전류 에 대하 ㄴ 열 적 상관 관계 를 분석 하 ㄴ 것 이 다 .',
#  '따라서 보 ㄴ 연구 에서 의 메카니즘 이 매우 다양 하 여 누전 상태 중 에서 전선 의 노출 상태 를 개방 및 밀폐 상태 로 구분 하 고 누전 개소 에 2 가지 의 시료 이 ㄴ 목분진 과 빗물 , 목탄 입력 등 의 한정 하 여 누설 전류 에 대하 ㄴ 열적데이터 를 추출 하 고 , 그 위험 성 을 분석 하 는 것 에 목적 이 있 다 .',
#  '일반 적 으로 누전 과 지락 의 경우 의 같 은 의미 의 용어 로 사용 되 나 , 지락 의 경우 지락 회로 가 즉시 형성 되 는 반면 누전 은 많 은 시간 을 두 고 누전 되 ㄴ 개소 에 누전 경로 를 형성 하 는 경우 로 다소 차이점 을 두 고 있 다 . 10 )',
#  '지락 ( 地絡 ) 은 전류 가 흐르 는 상태 에서 절연 부분 이 열화 또는 손상 되 어 충전부 가 타물체 와 접촉 되 어 대지 로 전기 가 흐르 는 것 을 말 하 ㄴ다 .',
#  '누전 이란 전선 의 절연 부분 이 열화 되 거나 불량 또는 손상 되 어 일정량 이하 의 전류 가 새 는 것 을 말 하 ㄴ다 .',
#  '누전 은 매우 다양 하 ㄴ 조건 과 환경 에서 발생 되 며 , 본 연구 에서 는 2 가지 의 상태 이 ㄴ 개방 되 ㄴ 상태 와 밀폐 되 ㄴ 상태 ( 분전반 내 ) 에서 누설 전류 값 을 증가 시키 었 고 , 누전 개소 에 도전 성 통로 를 형성 하 기 위하 여 전극 과 전극 사이 에 재료 를 추가 하 는 형태 로 첫째 목 분진 과 빗물 을 첨가 하 ㄴ 경로 와 목탄 만 으로 구성 하 ㄴ 경로 로 2 가지 경로 에서 각각 실험 하 였 다 .',
#  '본 연구 의 목적 을 달성 하 기 위하 여 누전화재 를 발생 시키 는 열 적 현상 에 대하 ㄴ 자료 및 논문 등 을 분석 하 였 고 , 누전 을 모의 하 기 위하 여 하트라인 ( R 상 ) 에 누전 회로 를 형성 하 여 , 각상태 마다 누전 개소 에 첨가물 을 입력 하 였 다 .',
#  '첨가물 은 목조 재질 에 빗물 이 유입 되 는 것 을 가정 하 고 , 전기 설비 에 누전 이 축적 되 어 탄화 경로 를 형성 하 ㄴ다는 가정 ( 맑 은 날 에 도 누전 이 가능 하 다는 조건 ) 하 의 목탄 ( 木炭 ) 가루 를 누전 개소 에 첨가 하 는 형태 로 구성 하 였 다 .',
#  '누전 개소 에 목 분진 과 빗물 및 목탄 입력 에서 , 누설 전류 값 에 대하 ㄴ 열 에 너지 분석 을 통하 여 전기 설비 에 어떠 하 ㄴ 영향 을 미치 는지 를 분석 하 였 다 .',
#  '누전 개소 에 목 분진 과 빗물 및 목탄 입력 에서 , 누설 전류 값 에 대하 ㄴ 열 에 너지 분석 을 통하 여 전기 설비 에 어떠 하 ㄴ 영향 을 미치 는지 를 분석 하 였 다 .',
#  '누전 은 매우 다양 하 ㄴ 조건 과 환경 에서 발생 되 며 , 본 연구 에서 는 2 가지 의 상태 이 ㄴ 개방 되 ㄴ 상태 와 밀폐 되 ㄴ 상태 ( 분전반 내 ) 에서 누설 전류 값 을 증가 시키 었 고 , 누전 개소 에 도전 성 통로 를 형성 하 기 위하 여 전극 과 전극 사이 에 재료 를 추가 하 는 형태 로 첫째 목 분진 과 빗물 을 첨가 하 ㄴ 경로 와 목탄 만 으로 구성 하 ㄴ 경로 로 2 가지 경로 에서 각각 실험 하 였 다 .',
#  '밀폐 되 ㄴ 공간 즉 , 분전반 내부 에 탄화흔적 이 보이 면 전기 설비 의 교체 나 정비 를 통하 여 탄화 현상 이 지속 되 는 것 을 방지 하 ㄹ 필요 가 있 다 .',
#  '목 분진 과 빗물 의 경우 , 개방 상태 와 밀폐 상태 모두 90 mA 에서 포화 되 어 더 이상 온도 의 증가 가 나타나 지 않 았 고 , 온도차 1 ~ 4 o C 로 비슷 하 ㄴ 온도 특성 을 보이 었 으나 , 목탄 의 경우 는 120 mA 까지 온도 상승 을 보이 었 고 , 개방 상태 에서 238 . 6 o C 와 밀폐 상태 는 357 o C 로 누전 되 ㄴ 전선 피복 , 분전 반 플라스틱 , 나무판 등 의 탄화 ( 재질 의 변형 ) 되 ㄹ 수 있 는 높 은 온도 가 나타나 았 다 .',
#  '누전화재 는 개방 또는 국소 밀폐 , 누전 경로 를 형성 하 였 는지 , 누전 경로 에서 화재 로 진전 되 ㄹ 충분 하 ㄴ 열 적 에너지 가 가능 하 ㄴ지 등 의 보다 구체 적 으로 제시 하 ㄴ다면 누전화재 의 화재 건수 를 줄이 ㄹ 수 있 을 것 으로 판단 되 ㄴ다 .',
#  '따라서 보 ㄴ 연구 에서 는 강원도 등 우리나라 8 개 기관 의 산불 담당 관련 부서 담당자 들 을 대상 으로 산불 교육 과정 , 희망교과목 , 산불방지 종합 훈련장 , 개편 내용 등 을 설문 조사 를 통하 여 산불 교육 훈련 개선 방안 의 기초 자료 를 제공 하 고자 하 ㄴ다 .',
#  '본 연구 는 국내 산불 훈련 기관 이 ㄴ 산림 인력 개발원 의 산불 교육 훈련 을 대상 으로 설문 조사 및 현장 인터뷰 를 통하 여 수행 하 였 다 .',
#  '가 . 조사 대상 : 강원도 , 경기도 , 충청남도 , 경상북도 , 지방산 림관리 청 ( 동부 , 남부 , 서부 ) , 산림항 공 관리 본부 등 총 8 개 기관 의 산불 담당 관련 부서',
#  '다 . 대상 기관 설문 참여율 : 대상 기관 의 전체 설문 대상자 는 280 명 이 었 고 , 257 명 이 응답 하 여 참여율 은 91 . 8 % 이 었 다 .',
#  '나 . 조사 시기 : 2008 년 9 월 20 일 ~ 10 월 30 일',
#  '표본 집단 은 산불 담당 근무 년수 , 직급 구분 , 산불 담당 업무 비율 , 산불 직무 관련 교육 훈련 경험 등 응답자 의 기본 정보 를 우선 적 으로 수집 하 여 각 조건 에 대하 ㄴ 비율 을 고려 하 여 257 명 의 표본 집단 을 선정 하 였 다 .',
#  '라 . 조사 방법 : 가능 하 ㄴ 한 설문 내용 을 설명 한 후 설문지 를 나누 어 주 거나 공문서 를 통하 여 회신 하 여 참여율 이 높 았 으며 , 여의 하 지 않 은 경우 이메일 ( E - mail ) 을 통하 여 회수 하 였 다 .',
#  '마 . 통계 처리 : 설문지 회수 결과 기초 통계량 은 엑셀 프로그램 을 통하 여 계산 되 었 으며 , 필요 에 따르 아 SPSS 통계 패 키 지 12 . 0 을 사용 하 여 분석 하 였 다 .',
#  '1 . 산림 인력 개발원 에서 실시 하 ㄴ 교육 내용 을 보 면 강의 와 실습 시간 은 68 : 32 의 비율 로 구성 되 어 실습 시간 이 적 었 고 , 설문 응답 에서 도 교육 과정 및 교과목 개편 요구 가 39 % , 48 % 잇 었 다 .',
#  '즉 , 교육 과정 별 교목 을 분석 하 여 보 면 5 ~ 6 급 과정 은 산불 진화 지휘 과정 ( 해외 ) , 산불 대응 관계관 과정 이 있 고 , 6 급 이하 과정 은 산불 방지 실무 과정 , 산불 진화 지휘 과정 ( 국내 ) , 산불 상황 관리자 과정 , 산림 보호 강화 사업 담당자 과정 등 이 있 는데 , 이 들 과정 의 교과목 들 이 대부분 중복 되 어 있 거나 유사 과목 으로 편성 되 어 있 고 , 교육 수준 별 로 편성 되 어 있 지 않 았 고 , 특히 실습 위주 보다 는 강의 등 이론 교육 에 치중 하 는 것 으로 나타나 았 다 .',
#  '4 . 더불 어 , 산불방지 종합 훈련장 개편 제안 에서 는 산불 초급 과정 부터 전문 과정 에 이르 기 까지 현장 위주 의 산불 예방 교육장 , 초기 단계 진화 훈련장 , 확산 단계 진화종합 훈련장 , 사후 관리 단계 및 안전 관리 훈련장 등 산불 진화 교육 이 단계 별 로 체계 적 으로 이루어지 ㄹ 수 있 는 훈련장 으로 개편 하 며 , 산불 진화 훈련장 개선 시 추가 로 신설 을 희망 하 는 실습 내용 은 산불 현장 감식 , 기상 변화 측정 실습 , 심폐 소생술 , 응급 처치기술 훈련 등 이 었 다 .',
#  "정리 하 면 담당 직무 와 관련 산림 인력 개발원 산불 교육 과정 에 대하 여 73 % 가 ' 자 기 개발 및 업무 수행 에 도움 이 되 었 다 ' 라고 인식 하 는 반면 , 나머지 27 % 는 그다지 만족 하 지 않 고 있 음 을 알 ㄹ 수 있 었 다 .",
#  '설문 분석 을 통하 여 우리 가 알 ㄹ 수 있 었 던 것 은 교육 과정 , 교과목 , 산불방지 종합 훈련장 의 시설 등 의 개편 요구 가 크 ㄴ 것 으로 나타나 았 다 .',
#  '2 . 기존 의 산불 교육 과정 중 산불 전문 예방 · 진화대과정 , 산림 보호 강화 사업 담당자 과정 , 산불 상황 관리자과정 은 실무자 과정 에 통합 하 고 , 산불방지 실 무 과정 , 산불 진화 지휘 과정 ( 국내 ) 은 중견 실무자과정 에 통합 하 며 , 산불 진화 지휘 과정 ( 해외 ) , 산불 대응 관계관과정 은 고급 관리자과정 에 통합 하 며 , 산림생태환 경 교원반 , 청소년 산림 체험반 등 은 특별 교육 과정 에 포함 시키 ㄹ 것 을 제안 하 ㄴ다 .',
#  '5 . 산불재해 는 직무 분야 - 교육 훈련 분야 - 실무 분야 가 상호 연관 성 있 게 운영 되 어야 산불 방지 에 대하 ㄴ 대응 능력 을 최대한 발휘 하 ㄹ 수 가 있 다 .',
#  '3 . 산불방지 종합 훈련장 도 교육 훈련 대상 및 교육 내용 에 있 어 과거 에 비하 여 교육 내용 이 변경 되 ㅁ 에 따르 아 현재 설치 되 어 있 는 단순 진화 훈련장 을 산불 확산 단계 별 진화 대응 이 가능 하 도록 개편 하 ㄹ 필요 가 있 고 , 노후 화 되 ㄴ 진화 장비 를 시대 조류 에 맞 게 최 신 형 및 진화디지털지휘 장비 로 의 교체 가 필요 하 다 .',
#  '본 연구 에서 는 수치 해석 을 통하 여 배기덕트 의 형태 에 따르 ㄴ 위치 별 유동 특성 과 발열 량 산정 변수 들 의 편차 를 수치 적 으로 해석 하 여 유동 형태 에 따르 ㄴ 주요 물성 의 상대 적 불 확실 성 을 비교분석 하 므로 서 효율 적 이 ㄴ 발열량 측정 을 위하 ㄴ 설계 인자 들 의 개선 방향 을 제시 하 고자 하 ㄴ다 .',
#  '후드 와 덕트 벽면 에서 의 방사 율 은 0 . 9 를 가정 하 였 으며 외부 로 의 대류 열 전달 의 영향 을 고려 하 기 위하 여 외기 와 후드 및 덕트 표면 사이 의 대류 열전달 계수 는 10 W / m 2 K , 외기 온 도 는 298 K 으로 가정 하 ㄴ다 .',
#  '본 연구 에서 는 두 가지 형태 에 대하 여 동 일 하 ㄴ 유동 조건 을 적용 하 기 위하 여 기준 이 되 는 수직덕트 구조 에 대하 여 주어지 ㄴ 압력 조건 ( ∆ p = 50 Pa ) 에 대하 ㄴ 측정면 에서 의 질량유량 을 먼저 산정 하 ㄴ다 .',
#  '본 연구 의 해석 대상 은 미국 립표준 기 술 연구원 ( NIST ) 의 대형 화 재 실험 동 내 에 설치 되 ㄴ 3 m × 3 m 후드 를 가지 ㄴ 발열량 계 로서 최대측정 발열량 이 약 1 MW , 지속 측정 가능 발열량 은 약 500 kW 정도 로 설계 되 었 으며 주로 가 구 나 단일가연물 의 화재 강도 를 측정 하 는데 이용 되 ㄴ다 .',
#  '본 연구 는 수치 해석 을 통하 여 화재 발 열량 계 내부 의 열유동 및 물질 전달 특성 을 파악 하 여 발열 량 산정 의 불 확실 성 에 영향 을 미치 는 주요 인자 들 의 특성 을 파악 하 고 측정 위치 를 최적 화 하 기 위하 ㄴ 측정 인자 들 의 상대 적 이 ㄴ 기여분 을 분석 하 였 다 .',
#  '그림 에서 보 는 것 처럼 수 직 덕 트 구조 의 경우 평면 방향 의 속도 성분 이 1 % 이하 로 나타나 았 지만 수 평 덕트 구조 의 경우 곡관부 를 통과 하 ㄴ 직후 11 % 이상 의 평면 방향 속도 성분 을 보이 고 있 으며 배기관 의 출구 에서 도 2 % 이상 을 나타내 고 있 다 .',
#  '범용 수치 해석 모델 을 이용 하 여 화원 주위 의 화재 유동 및 후드 및 덕트 시스템 에서 의 유동 을 모델링 하 였 으며 발열량 계 설계 의 최적화 과정 에 수치 해석 모델 이 유용 하 ㄴ 도구 로 활용 되 ㄹ 수 있 음 을 보이 어 주 ㄴ다 .',
#  '방향 유속 계 의 경우 사용 상 의 편의 성 으로 인하 여 화재발 열량 계 에 사용 되 고 있 으나 평면 방향 의 속도 성 분 으로 인하 ㄴ 오차 나 유동장 에 미치 는 영향 으로 측정점 이 제한 되 기 때문 에 배기덕트 의 평균 유속 을 정확히 측정 하 여야 하 는 화재 발열량 계 에 대하 여서 는 효과 적 이 지 못하 ㄴ 측정 기법 으로 나타나 았 다 .',
#  '발열량 산정 에 필요 하 ㄴ 측정 변수 중 각 측정 단면 에서 편차 가 가장 크 ㄴ 변수 는 유동 속도 이 며 온도 의 변차 가 가장 적 은 것 으로 나타나 았 다 .',
#  '이러 하 ㄴ 연구 를 통하 여 신뢰 성 높 은 화재 발 열 량 계 의 구축 을 위하 ㄴ 설계 과정 을 최적 화 하 고 효율 적 이 ㄴ 시스템 운영 을 위하 ㄴ 기초 자료 로 활용 되 ㄹ 수 있 으며 발열량 측정 의 신뢰 성 향상 을 위하 ㄴ 화재 측정 기법 의 개선 방향 을 제시 하 고자 하 ㄴ다 .',
#  '따라서 지속 적 이 ㄴ 노력 을 통하 여 화재 유동 측정 의 신뢰 성 을 향상 시키 고 화재 발 열량 계 적용 에 적합 하 ㄴ 유동 측정 기법 에 대하 ㄴ 연구 가 필요 하 다 .',
#  '그러나 이러 하 ㄴ 과정역시 불 확실 성 을 내재 하 고 있 으며 근복 적 으로 는 유동 측정 기법 의 개선 을 통하 여 대표 속도 값 의 신뢰 성 을 향상 시키 기 위하 ㄴ 노력 이 필요 하 다 .',
#  '이 에 따르 아 현재 규제 화 가 되 지 않 은 피난유 돕 음 시스템 을 실제 적용 하 기 위하 여 기본 적 이 ㄴ 음향 특성 을 파악 하 고 효과 적 이 ㄴ 유도음 선정 에 대하 여 조사 하 고자 하 ㄴ다 .',
#  '피난 유도등 은 빛 으로 인하 여 유도 하 는 시스템 이 며 , 피난 유도 표지 는 이미지형상 으로 피난 방향 을 알리 는 표시판 이 다 .',
#  '본 연구 는 화재 피해 의 최소 화 를 위하 ㄴ 근본 적 대책 중 의 하나 이 ㄴ 유도 시스템 에 필수 적 이 ㄴ 피난 유도음 도출 을 위하 ㄴ 기초 연구 로서 , 소방 공무원 과 일반인 을 대상 으로 피 난자 들 의 화재 에 대하 ㄴ 일반 의식 과 선호 피난 유도음 을 파악 하 기 위하 ㄴ 설문 조사 를 실시 하 였 다 .',
#  '임 의 표집 대상 은 초등학생 , 대학 생 그리고 일반인 과 화재 현장 에서 근무 하 는 소방 공무원 들 을 대상 으로 설문 을 배포 하 였 다 .',
#  '설문 대상자 들 중 에서 일반인 과 소방 전문인 들 로 나누 어 화재 의식 및 피난 경향 차이 를 살펴보 았 다 .',
#  '연구 대상 을 사회 조사 방법 론 에 나오 ㄴ 표집 방법 을 사용 하 기 란 비용 , 시간 등 의 문제 로 인하 여서 거의 불 가능 하 다고 판단 되 어 지 어 개인 의 논문 이나 보 고 서 등 을 작성 하 ㄹ 경우 에 많이 쓰이 는 임의 표집 방법 을 선택 하 였 다',
#  '이 를 위하 여 피난유 돕 음 시스템 에서 발현 되 는 음성 정보 의 구체 적 이 ㄴ 표현 방법 을 검토 하 ㄴ 다음 , 템포 와 음향 특성 을 변화 시키 어 배경 소음 하 에서 들려주 어 쉽 게 정보 의 내용 을 파악 하 ㄹ 수 있 는 것 에 대하 여 조사 하 고자 하 ㄴ다 .',
#  '배포 되 ㄴ 설문지 총 195 부 대하 여서 통계 프로그램 이 ㄴ SPSS 12 을 이용 하 여 통계 처리 하 였 다 .',
#  '화재 발생 시 견디 ㄹ 수 있 는 예상 시간 과 및 안전 하 게 피난 하 ㄹ 수 있 는 여유 시간 에 대하 ㄴ 조사 결과 , 여유 시간 이 매우 짧 은 것 으로 인식 하 고 있 어 초기 대응 에 대하 ㄴ 적절 하 ㄴ 대처 가 필요 하 다 .',
#  '시야 가 확보 되 지 않 는 상황 에서 피난 유도 시스템 의 피난 유도음 으로 여성 의 음성 으로 " 비상구 는 이 쪽 이 ㅂ 니 다 " 와 함께 싸이렌 , 빛 을 병용 하 는 피난 유도 하 는 시스템 을 가장 선호 하 였 다 .',
#  '본 연구 의 결과 로서 응답자 들 은 집 이나 직장 과 같 은 익숙 하 ㄴ 장소 에서 는 화재 안전 의식 이 점점 높 아 지 고 있 고 있 으나 , 새롭 ㄴ 공간 을 접하 였 을 경우 아직 도 화재 안전 의식 은 높 지 않 는 것 으로 나타내 었 다',
#  '본 연구 에서 도출 되 ㄴ 음성 정보 를 바탕 으로 적절 하 ㄴ 소리크기 를 가지 는 음성 피난유도 시스템 에 대하 여서 청감 실험 및 실제 현장 실험 을 하 여 최적 의 음성 피난유 도 시스템 을 개발 하 고자 하 ㄴ다 .',
#  '그러므로 보 ㄴ 연구 에서 는 고정단 조건 과 히 ㄴ 지 조건 에서 하중 축력비 에 대하 ㄴ CFT 각형 기둥 의 변형 특성 을 분석 하 고 이 에 따르 ㄴ 내화 성능 의 영향 성 을 분석 하 여 경계 조건 에 따르 ㄴ CFT 기둥 의 내화 성능 변화 를 제시 하 고자 보 ㄴ 연구 를 수행 하 였 다 .',
#  '그러므로 보 ㄴ 실험 에서 는 Figure 1 과 같 은 경계 조건 변동 이 가능 하 ㄴ 재하지 그 를 가열로 에 설치 하 여 실제 CFT 기둥 의 경계 조건 을 구현 하 여 재하가열 실험 을 수행 하 고자 하 였 다 .',
#  '콘크리트 가 충전 되 ㄴ 각 형 강관 기둥 ( CFT ) 은 외부 에 강재 가 노출 되 ㄴ 형상 으로 외측 의 강관 은 화재 시 급격 하 ㄴ 온도 상승 으로 인하 여 강도 가 저하 되 나 , 내부 의 콘크리트 는 열용량 이 크 ㄴ 재료 로써 내화 성능 을 확보 하 ㄹ 수 있 는 구조 로 구성 되 어 있 다 .',
#  '그러므로 CFT 구조 가 일 정 하 ㄴ 내화 설계 조건 을 만족 시키 면 내화 피복 이 없 는 구조 로 사용 이 가능 하 며 , 유럽 에서 는 비교 적 짧 은 요구 내화 성능 시간 에 확인 신청 의 절차 만 으로 무 내화 피복 CFT 구조 의 사용 을 인정 하 고 있 다 .',
#  '표준 화재 ( ISO Standard Fire ) 조건 에서 화재 실험 을 수행 하 였 으며 , 실험체 의 온도 와 변형 을 측정 하 여 KS F 2257 - 1 의 기준 에 의하 여 내화 성능 을 평가 하 였 다 .',
#  '이 에 보 ㄴ 연구 에서 는 기둥 부재 가 하중 을 받 을 때 의 실질 적 상황 조건 이 ㄴ 경계 조건 을 고온 조건 에서 구현 하 ㅁ 으로써 경계 조건 변화 에 따르 ㄴ 내화 성능 의 영향 성 에 대하 여서 분석 하 고자 실험 을 수행 하 였 다 .',
#  '화재 실험 을 통하 ㄴ CFT 기둥 의 강재 및 콘크리트 의 온도 와 변형 을 측정 하 고자 하 였 으며 , 열전대 는 K - Type 열전대 를 사용 하 여 강재부위 에 4 개 소 를 KS F 2257 - 1 의 규정 에 따르 아 철근 내부 에 드 릴 링 하 여 설치 하 였 다 .',
#  'CFT 각형 기둥 의 내화 성능 에 의 영향 인자 중 실제 구조물 에 적용 되 ㄴ 부재 의 경계 조건 을 고려 하 여 화재시 발생 하 ㄹ 수 있 는 내화 성능 변화 의 영향 성 을 분석 하 고자 내화 실험 을 수행 하 였 다 .',
#  '콘크리트 의 화재 노출 깊이 에 따르 ㄴ 온도 변화 를 분석 하 기 위하 여 가열 면 으로 부 터 의 깊이 에 따르 ㄴ 콘크리트 내부 의 온도 ( Table 2 : 열 전대 5 ~ 10 번위치 ) 를 Model - III 을 기준 으로 분석 하 였 다 .',
#  '360 × 360 단면 의 24 MPa 에서 축력비 0 . 6 조건 으로 내화 성능 영향 인자 의 조건 을 동일 하 게 유지 시키 고 내화 성능 을 평가 하 ㄴ 결과 , 양 단 고정 조건 에서 는 106 분 의 내화 성능 이 확보 되 나 양 단 히 ㄴ 지 조건 에서 는 89 분 의 내화 성능 을 확보 하 는 것 으로 나타나 았 으며 , 이 는 경계 조건 에 따르 아 약 17 분 의 내화 성능 의 차이 가 나타나 는 것 으로 Figure 10 과 같이 분석 되 었 다 .',
#  '경계 조건 에 따르 ㄴ CFT 기둥 의 온도 변화 를 분석 하 기 위하 여 실험 모델 별 기둥 의 중앙부 에서 의 강재 평균 온 도 ( Table 2 : 열 전대 1 ~ 4 번 위치 ) 를 비교 하 ㄴ 결과 , 경계 조건 자체 는 CFT 기둥 의 강재 부분 의 온도 에 영향 을 미치 지 는 않 았 다 .',
#  '경계 조건 에 따르 ㄴ CFT 기둥 의 콘크리트 내부 온도변화 를 분석 하 기 위하 여 실험 모델 별 콘크리트 의 이방향 열전달 조건 에서 가열 표면 의 강재 로부터 10 mm 이격 되 ㄴ 부위 ( Table 2 : 열전대 11 번 위치 ) 에서 의 모델 별 온도 를 분석 하 였 다 .',
#  '화재 시 대부분 의 내력 을 콘크리트 에서 분담 하 는 CFT 의 특성 을 고려 하 여 양 단 힌지 조건 의 실험체 ( Model - III ) 를 분석 하 였 다 .',
#  'CFT 기둥 의 표준 화재 ( ISO Standard Fire ) 조건 에서 화재 에 노출 되 ㄴ 강 재 의 위치 별 온도 변화 를 기둥 의 중앙부 에서 Model - III 을 대상 으로 분석 하 였 다 .',
#  '이 에 콘크리트 압축 강도 실험 을 위하 ㄴ 공시체 제작 은 KSF 2403 에 의거 하 였 고 , 압축 강도 실험 은 KS F 2405 에 의거 하 여 공시체 3 개 를 Figure 5 와 같이 실험 을 수행 하 였 다 .',
#  '280 × 280 단면 의 24 MPa 에서 축력비 0 . 6 조건 으로 내화 성능 영향 인자 의 조건 을 동일 하 게 유지 시키 고 내화 성능 을 평가 하 ㄴ 결과 , 양 단 고정 조건 에서 는 113 분 의 내화 성능 이 확보 되 나 양 단 히 ㄴ 지 조건 에서 는 78 분 의 내화 성능 을 확보 하 였 다 .',
#  '4 ) 단면크기 가 크 어 지 ㄹ수록 CFT 기둥 의 열용량 의 상승 으로 인하 여 보다 안정 적 이 ㄴ 거동 과 온도 분포 가 나타나 며 , 화재시 경계 조건 의 영향 에 의하 여 내화 성능 의 변화 가 발생 하 는 것 으로 판단 되 ㄴ다 .',
#  '2 ) 360 단면 의 24 MPa 에서 축력비 0 . 6 조건 으로 경계 조건 의 내화 성능 영향 성 을 분석 하 ㄴ 결과 , 양단 고정 조건 이 적용 되 ㄹ 경우 17 분 의 내화 성능 을 양 단 히 ㄴ 지 조건 에 비하 여 더 확보 하 ㄹ 수 있 는 것 으로 나타나 았 다 .',
#  '3 ) 280 × 280 단면 의 24 MPa 에서 축력비 0 . 6 조건 에서 는 양 단 고정 조건 이 양단 히 ㄴ 지 조건 에 비하 여 약 35 분 의 내화 성능 을 추가 적 으로 확보 하 는 것 으로 나타나 았 다 .',
#  '1 ) 경계 조건 변화 에 따르 아 CFT 기둥 의 내화 성능 을 평가 하 ㄴ 결과 , 양단 고정 이 양단 힌 지 에 비하 여 내화 성능 이 확보 되 ㄹ 수 있 는 것 으로 나타나 았 다 .',
#  '본 연구 에서 는 CFT 기둥 의 경계 조건 변화 에 따르 ㄴ 내화 성능 에 의 영향 성 을 분석 하 였 으며 , 향후 이러 하 ㄴ CFT 기둥 의 내화 성능 에 관하 ㄴ 실험 결과 를 토대 로 내화 성능 을 예측 하 ㄹ 수 있 는 해석기법 확보 와 내화 설계식 도출 에 관하 ㄴ 연구 가 추진 이 필요 하 ㄹ 것 으로 판단 되 ㄴ다 .',
#  "본 논문 은 스테인리스 강관중 중량 이 가볍 고 , 설치 가 간편 하 며 , 무용접 시공 이 가능 하 ㄴ 강관 이 ㄴ ' 일반 배 관 용 스테인리스 강관 ( KS D 3595 ) ' 에 사용 되 ㄹ 수 있 는 이음쇠 의 성능 을 평가 하 여 소화 설비 등 에 사용 되 ㄹ 수 있 는지 여부 를 판단 하 고자 하 ㄴ다 .",
#  "KS D 3595 ( JIS G 3448 ) 에서 규정 하 는 일반 배관 용 스테인리스 강관 의 접합 에 사용 하 는 메커니컬 형 파이프 이음쇠 에 적용 하 며 , ' 메카니컬 형 ' , ' 원터 치형 ' , ' 프레스식 ' , ' 너트 · 플랜 지식 ' 이 있 다 .",
#  "미국 , 일본 , 독일 , 네덜란드 , 호주 등 에서 소방 배관 으로 최근 사용 되 고 있 는 경량 ( light - gauge ) 스테인리스 강 관 이 ㄴ ' 일반 배 관 용 스 테인리스 강 관 ' 에 사용 되 는 이음쇠 에 대하 ㄴ 성능 평가 를 진동 시험 , 수격 시험 , 굽 힘시험 , 본체 강도 시험 , 내열 성 시험 , 화재 시험 , 내압 시험 을 통하 여 수행 하 였 다 .",
#  '이음쇠 는 최고 사용 압력 의 수압력 을 가 한상태 에서 이음부 중앙 에 다음 계산식 에 의하 ㄴ 굽힘모멘트 를 가하 ㄹ 경우 누설 또는 파손 등 이 생기 지 아니하 여야 하 ㄴ다 .',
#  '이음쇠 의 내열 성 시험 은 분기 배관 의 내열 성 시험 을 준용 하 였 다 . 이 음쇠 를 ( 1 , 000 ± 50 ) oC 로 유지 되 는 가열로 에 넣 어 30 분 간 유지 시키 ㄴ 후 시험편 을 꺼내 어 상온 까지 식히 었 을 때 , 변형 이 없 어야 하 며 본체 강도 시험 에서 누설 또는 변형 등 이 생기 지 아니하 여야 하 ㄴ다 .',
#  '이음쇠 를 길이 500 mm 이상 또는 관지름 의 5 배 중 크 ㄴ 값 의 관 에 이음쇠 의 의 연결 방법 과 동일 하 ㄴ 방법 으로 부착 하 여 다음 그림 과 같 은 시험 장치 에 부착 하 고 전진폭 5 m m , 진동수 10 Cycle / s , 정형파 의 진동 을 1 , 000 , 000 회 가하 면서 손상 · 변형 또는 누설 등 의 이상 여부 및 최고 사용 압력 의 1 . 5 배 수압력 을 5 분 간 가하 는 경우 누 수 되 거나 변형 여부 를 확인 하 ㄴ다 .',
#  '경량 스테인리스강관 에 사용 되 는 이음쇠 의 성능 시험 또한 , 이 기준 에 근거 하 여 부족 하 ㄴ 시험 은 다른 시험 기준 을 참고 하 였 으며 , 여러 시험 항목중 대표 적 이 ㄴ 시험 이 ㄴ 진동 시험 , 수격 시험 , 굽 힘시험 , 본체 강도 시험 , 화재 시험 및 내압 시험 을 수행 하 였 다 .',
#  '스테인리스 강관 의 내화 성능 을 확인 하 기 위하 여 「 소방 용 합 성 수지배관 의 성능 시험 기술 기준 」 제 16 조 12 ) 의 시험 방법 을 이용 하 였 다 .',
#  '이음쇠 의 내열 성 시험 은 분기 배관 의 내열 성 시험 을 준용 하 였 다 .',
#  '이 음쇠 를 ( 1 , 000 ± 50 ) oC 로 유지 되 는 가열로 에 넣 어 30 분 간 유지 시키 ㄴ 후 시험편 을 꺼내 어 상온 까지 식히 었 을 때 , 변형 이 없 어야 하 며 본체 강도 시험 에서 누설 또는 변형 등 이 생기 지 아니하 여야 하 ㄴ다 .',
#  'Table 3 의 조건 과 같 은 크기 의 시험장 에 2 . 4 m 높이 의 천장 에 스프링클러 배관 을 설치 하 ㄴ 후 헵 탄 24 L 를 넣 고 화재 시험 을 실시 하 ㄴ 후 , 배관 등 에 최고 사용 압력 을 5 분 간 가하 는 경우 파손 , 누수 등 을 확인 하 ㄴ다 .',
#  '이음쇠 는 길 이 500 mm 이상 또는 관지름 의 5 배 중 크 ㄴ 값 의 관 에 이음쇠 의 연결 방법 과 동일 하 ㄴ 방법 으로 내압 시험기 에 시료 를 부착 하 고 최고 사용 압력 ( 1 . 4 MPa ) 의 1 . 5 배 에 해당 하 는 압력 을 가하 는 경우 에 누수 또는 변형 등 이 생기 지 아니하 여야 하 ㄴ다 .',
#  '이음쇠 를 길이 500 mm 이상 또는 관지름 의 5 배 중 크 ㄴ 값 의 이음쇠 를 수격 시험기 ( 피스톤 형 펌프 등 ) 에 부착 하 여 이음쇠내 의 공기 를 완전히 제거 하 ㄴ 상태 에서 매초 0 . 35 MPa 로부터 3 . 5 MPa 까지 의 압력 변동 을 연속 하 여 4 , 000 회 가하 ㄴ 후 최고 사용 압력 의 1 . 5 배 수압력 을 5 분 간 가하 는 경우 누 수 되 거나 변형 여부 를 확인 하 ㄴ다 .',
#  '배관 에 부착 되 는 형태 로 내압 시험기 에 시료 를 부착 하 고 호칭 지름 150 이하 의 이음쇠 에 대하 여 는 최고 사용 압력 의 5 배 의 압력 , 호칭 지름 200 이상 의 이음쇠 에 대하 여 는 최고 사용 압력 의 4 배 의 압력 을 균열 · 영구 변형 또는 파손 등 의 상태 를 확인 하 ㄴ다 .',
#  'Figure 7 및 Figure 8 과 같이 1 , 000 , 000 회 를 가하 는 약 28 시 간 의 진동 시험 의 결과 는 누수 또는 변형 등 이 일어나 지 않 았 으며 , 참고 시험 으로 배관 내 수압력 이 ㄴ 1 . 1 MPa 을 가하 ㄴ 상태 에서 도 진동 시험 을 시행 하 여 보 았 으며 , 시험 종료 후 내압 시험 ( 최고 사용압력 의 1 . 5 배 ) 을 확인 하 ㄴ 결과 제품 에 누 수 나 변형 등 의 발생 이 없 었 다 .',
#  '또한 , 그 성능 을 확인 하 면서 도출 되 ㄴ 인자 를 가지 고 이음쇠 의 수명 을 예측 하 ㄴ 결과 진동 성능 으로 평가 하 ㄴ 수명 은 100 년 이상 , 고무링 의 수명예측 값 은 80 oC 의 경우 약 88 년 이 ㅁ 을 예측 하 ㄹ 수 있 었 다 .',
#  '따라서 , 선진 각국 에서 수계 소화 설비용 배관재 로 사용 되 고 있 는 경량스테인리스 강관용 이음쇠 를 스프링클러설비 등 의 관련 화재 안전 기준 에 도입 하 ㄹ 경우 충분 하 ㄴ 성능 이 있 음 을 확인 하 였 고 국내 에서 생산 되 고 있 는 제품 으로 도 사용 가능 하 ㅁ 을 판단 하 ㄹ 수 있 었 다 .',
#  '스테인리스 강 관 에 사용 되 는 이음쇠 의 강도 는 내압 , 본체 강도 , 굽 히 ㅁ , 수격 성능 시험 을 통하 여 그 사용 가능 성 을 평가 하 였 으며 누수 · 균열 · 파손 등 이 발생 하 지 않 아 충분 하 ㄴ 강도 를 가지 고 있 었 다 .',
#  '내열 성 은 내열 성 및 화재 시험 으로 그 성능 을 확인 하 였 고 그 성능 의 변화 가 없 어 충분 하 ㄴ 내열 성 을 가지 고 있 었 음 을 확인 하 였 다 .',
#  'Figure 15 와 같이 화재 시험 을 실시 하 ㄴ 후 , 내압 시험 을 통하 여 그 성능 을 확인 하 ㄴ 결과 Figure 16 과 같이 파손 , 누수 등 이 이상 이 없 었 다 .',
#  '내압 시험 에서 이상 이 없 었 으며 , 진동 시험 후 Figure 17 과 같이 , 수격 시험 후 Figure 18 과 같이 또한 굽 힘시험 후 내압 시험 을 실시 하 ㄴ 결과 모든 제품 에서 누수 나 변형 등 이 발생 하 지 않 았 다 .',
#  '내열성 시험 결과 변형 이 없 었 으며 , 본체 강도 시험 결과 또한 이상 이 없 었 다 .',
#  'Figure 13 과 같이 해당 압력 으로 본체 강도 시험 을 5 분 동안 가하 ㄴ 결과 이상 이 없 었 다',
#  'Figure 9 와 같이 시험 하 ㄴ 결과 시료 의 연결부 및 압착부 에서 Figure 10 과 같이 약간 의 이격 은 발생 되 었 으나 누수 나 변형 등 의 이상 은 발견 되 지 않 았 다 .',
#  'Figure 11 및 Figure 12 와 같이 굽 힘모멘트 를 가하 ㄴ 결과 누수 또는 변형 등 이 일어나 지 않 았 으며 , 참고 시험 으로 1 . 1 MPa 의 배관 내 수 압력 을 가하 여 비교 시험 을 하 여 보 ㄴ 결과 , 두 조건 모두 이상 이 없 었 으며 , 시험 종료 후 내압 시험 ( 최고 사용압력 의 1 . 5 배 ) 을 확인 하 ㄴ 결과 제품 에 누 수 나 변형 등 이 발생 하 지 않 았 다 .',
#  '이러 하 ㄴ 평가 방법 은 향후 국내 소방 제품 의 수명 을 평가 하 는데 사용 이 가능 하 며 , 내 구 연한 을 정하 는 판단 자료 로 활용 하 고자 하 ㄴ다 .',
#  '본 연구 에서 는 제조물 관련 화재 의 조사 과정 에서 나타나 는 문제점 을 살펴보 고 그 개선 방안 을 도출 하 였 다 .',
#  '두 번 째 가설 은 냉장고 냉동실 내부 에서 전기 적 원인 에 의하 여 처음 화재 가 발생 하 였 고 , 화염 이 냉장 고위 에 있 었 던 전자렌지 로 연소 확대 되 었 다 . 그리고 냉장고 위 에 있 었 던 전자렌지 가 냉동실 내부 로 떨어지 었 다 .',
#  '첫 번 째 가설 은 냉장고 위 에 있 었 던 전자렌지 내부 에서 전기 적 원인 에 의하 여 화재 가 발생 하 였 으며 , 냉장고 냉동실 플라스틱 재질 의 상부 ( 지붕 ) 를 태우 고 냉동실 안 으로 떨어지 었 다 .',
#  '2010 년 8 월 10 일 11 : 58 경 강원도 화천군 화천읍 소재 모 연립 주택 3 층 에서 화재 가 발생 하 여 냉장고 와 냉장고 위 에 있 었 던 전자렌지 가 전소 되 었 으며 , 약 42 . 9 m 2 내부 가 그 을 리 ㅁ 피해 를 입 었 다 .',
#  '즉 , 문헌 을 통하 여 화재 조사 에 관하 ㄴ 이론 적 고찰 을 하 였 으며 , 제조물 관련 화재 조사 사례 를 중심 으로 고찰 하 였 다 .',
#  '본 연구 는 제조물 결함 으로 인하 여 화재 가 발생 하 였 을 때 어떻 게 화재 조사 가 진행 되 는지 를 사례 를 중심 으로 살펴보 고 문제점 과 개선 방안 을 도출 하 였 다 .',
#  '연구 결과 , 화재 조사 관련 법률 이 분산 운영 되 ㅁ 에 따르 아 화재 조사 현장 에서 조종자 역할 을 하 는 주체 가 불 분 명 하 ㄴ 것 으로 나타나 았 으며 , 화재 피해 를 입 은 이재민 들 의 권익 보호 를 위하 ㄴ 제도 적 장치 가 부족 하 고 , 소방 의 화재 감정 기관 이 없 어 화재원인 도출 에 한계 가 있 는 것 으로 나타나 았 다 .',
#  "이러 하 ㄴ 문제점 을 개선 하 기 위하 여서 는 소방 이 화재 조사 현장 에서 참석 하 ㄴ 이해 관계자 들 의 조종자 역할 을 하 ㄹ 수 있 는 제도 의 도입 , 화재 피해이재민 의 권익 보호 를 위하 ㄴ 가칭 ' 민간 화재 조사 전문가 ' 제도 의 도입 , 국립 과 학 수사연구원 이외 의 소방 에 화재 감정 기관 및 연구소 의 설립 · 운영 , 소방 과 제조물 회사 와 의 네트워크 구성 등 이 필요 하 ㄴ 것 으로 나타나 았 다 .",
#  '본 연구 에서 는 동축류 버너 를 이용 하 ㄴ 제트확산 화염 에서 산화제 측 에 이산화탄소 를 첨가 하 여 이산화탄소 가 매연 의 생성 에 미치 는 영향 을 실험 적 으로 조사 하 였 다 .',
#  '또한 매연 의 정량 적 이 ㄴ 분석 을 위하 여 광감 쇄법 을 이용 하 여 상대 적 이 ㄴ 매연농 ( relative soot density ) 를 측정 하 였 고 열 적 효과 에 의하 ㄴ 매연 감소 를 규명 하 기 위하 여 산화제 의 유속 이 매연 에 미치 는 영향 을 알아보 았 다 .',
#  '본 논문 은 동축류 제트 화 염 을 이용 하 여 이산화탄소 의 첨가 가 매연 입자 의 생성 과 성장 에 미치 는 영향 을 정성 적 정량 적 으로 연구 하 였 다 .',
#  '이산화탄소 의 첨가 가 화염대 의 온도 에 미치 는 영향 을 정량 적 으로 알아보 기 위하 여 R - type 열전대 를 사용 하 여 청염 과 황염 부분 에서 각각 온도 를 측정 하 였 다 .',
#  '1 ) 보 ㄴ 실험 조건 에서 산화제 측 에 이산화탄소 를 첨가 하 ㅁ 에 따르 아 명멸 과 같 은 화염 의 불 안정 성 이 증가 하 였 다 .',
#  '4 ) 산화제 의 유속 증가 에 의하 여 매연 의 농도 가 감소 하 였 는데 이 는 산화제 의 유속 증가 에 의하 ㄴ 화염면 의 열손실 로 인하 여 궁극 적 으로 화염 의 온도 가 감소 하 였 기 때문 으로 생각 되 ㄴ다 .',
#  '3 ) 산화제 측 에 이산화탄소 를 첨가 하 ㅁ 에 따르 아 화염온도 는 점차 감소 하 였 고 이 로 인하 여 상대 적 이 ㄴ 매연 농도 는 낮 아 지 었 다 .',
#  '또한 청염 과 황염 의 경계 지점 의 온도 는 이산화탄소 의 첨가 에 관계없이 비교 적 일정 하 게 유지 되 었 는데 이 로써 매연 의 전구체 가 특정 온도 이상 에서 생성 되 ㅁ 을 확인 하 였 다 .',
#  '반 밀폐 공간 의 화재 상황 에서 이산화탄소 의 재첨가 가 매연생성 에 미치 는 영향 을 규명 하 기 위하 ㄴ 기초 연구 로써 보 ㄴ 연구 에서 는 층류 확산 화염 을 대상 으로 하 였 지만 , 향후 실제 화재 를 모사 하 기 위하 여 부력 이 지배 적 이 ㄴ 난류 확산 화염 을 대상 으로 하 ㄴ 연구 가 필요 하 다고 사료 되 ㄴ다 .',
#  '지금 까지 갯방풍 의 이차 대사 물질 에 대하 ㄴ 수 편 의 논문 이 발표 되 ㄴ 바 있 으나 우리나라 에 자생 하 는 갯방풍 의 이차 대사 물질 에 대하 ㄴ 연구 는 지방산 이나 스테롤 또는 정유 성분 을 제외 하 고 는 거의 연구 가 이루어지 지 않 았 다 .',
#  '본 연구 에서 는 우리나라 에 자생 하 는 갯방 풍 에서 추가 적 으로 분리 되 ㄴ 3 가지 화합물 과 이 들 의 구조 결정 및 생리 활성 에 대하 여 보고 하 고자 하 ㄴ다 .',
#  '화합물 의 구조 동정 은 Varian NMR ( 300 MHz ) 을 사용 하 였 으며 NMR 측정 용매 는 CD 3 OD 와 CDCl 3 ( Cambridge Isotope Laboratories , Inc . , USA ) 를 사용 하 였 다 .',
#  '실험 에 사용 하 ㄴ 갯방 풍 ( Glehnia littoralis ) 은 2004 년 9 월 경상북도 포항 시 해안 에서 직접 채집 하 여 경성대학교 문성기 박사 에 의하 여서 동정 되 었 으며 응달 에서 건조 후 추출 하 기 전 까지 - 25 ℃ 에서 냉동 보관 하 였 다 .',
#  '갯방풍 의 85 % aq . MeOH 분획 층 4 g 을 aq . MeOH 용액 ( 50 , 60 , 70 , 80 , 90 % aq . MeOH and 100 % MeOH ) 을 이용 하 여 C 18 역상 진공 칼럼 크 로마 토그래피 를 실시 하 였 으며 7 개 의 fractions ( rfc 1 ~ 7 ) 를 얻 었 다 .',
#  '갯방풍 으로부터 분리 되 ㄴ 화합물 5 - 7 의 세포 내 활성 산소종소거 효과 는 섬유 육종 세포 이 ㄴ HT - 1080 을 사용 하 였 으며 형광 염료 이 ㄴ DCF - DA 가 세포 내 생성 되 ㄴ 자유 이 라 디칼 과 반응 하 여 형광 물질 이 ㄴ DCF 로 산화 되 는 원리 를 이용 하 여 측정 하 였 다 .',
#  '갯방 풍 85 % aq . MeOH 분획 과 n - hexane 분획 을 칼럼 크 로마 토그래피 , Si prep . TLC 그리고 역상 HPLC 를 차례 로 수행 하 여 7 개 의 화합물 을 분리 하 였 다 .',
#  '이러 하 ㄴ NMR 분광 데이터 에 근거 하 여 문헌 조사 를 실시 하 ㄴ 결과 이 화합물 은 알리 어 지 ㄴ 화합물 이 ㄴ scopoletin 으로 확인 되 었 다 . 19 , 20',
#  '갯방풍 으로부터 분리 되 ㄴ 화합물 5 - 7 의 DPPH 라디 칼 소거 활 성 정도 는 Fig . 2 와 같이 나타나 았 으며 , control 과 비교 하 였 을 때 Vit . C 와 BHT 가 500 μ M 농도 에서 각각 96 . 7 . 83 . 8 % 의 높 은 DPPH 라디 칼 소거 활 성 을 보이 는데 비하 여 화합물 5 - 7 은 각각 10 . 2 , 12 . 4 , 12 . 5 % 의 낮 은 활성 을 나타내 었 다 .',
#  'Fig . 4 와 같이 화합물 3 종 의 ROS 소거능 은 시료 를 처리 하 지 않 고 H 2 O 2 만 을 처리 하 ㄴ control 과 비교 하 여 모두 농도 의존 적 으로 ROS 를 소거 하 는 것 으로 확인 되 었 으며 그 중 화합물 5 의 경우 50 μ M 농도 에서 control 대비 가장 높 은 활성 산소종 소거능 을 보이 어 주 었 다 .',
#  'AGS , HT - 29 세포 에 대하 여 화합물 5 - 7 을 각각 50 , 10 , 5 μ M 의 농도 로 처리 하 ㄴ 결과 화합물 7 을 50 μ M 의 농도 로 처리 하 였 을 때 에 AGS 위암 세포 에 대하 여 93 % 의 높 은 암세포 증식 억제 효과 를 보이 는 것 을 관찰 하 ㄹ 수 있 었 다',
#  '보다 근본 적 이 ㄴ 문제 해결과 묽 은 자성 반도체 물질 이 스 핀트로 닉 스 소자 로 응용 되 기 위하 여서 는 좀 더 많 은 연구 와 실험 을 바탕 으로 한 명확 하 ㄴ 물리 적 설명 이 필요 하 ㄴ 상황 이 다 .',
#  '본 연구 에서 는 Zn 1 - xCoxO ( x = 1 % ~ 15 % ) 묽 은 자성 반도체 물질 을 졸 - 겔 법 ( sol - gel ) 을 이용 하 여 단일상 의 전구체 를 합성 제조 하 였 다 .',
#  '묽 은 자성 반도체 는 주로 II - V 족 이 나 III - V 족 반도체 의 원소 일부 를 망간 ( Mn ) , 코발트 ( Co ) , 철 ( Fe ) 등 의 전 이 금속 ( transition metal ) 으로 일부분 치환 하 였 을 경우 기본 적 이 ㄴ 반도체 의 특성 은 그대로 유지 되 며 특정 온도 이하 에서 강자 성 ( ferromagnetism ) 이나 반강자 성 ( antiferromagnetism ) 등 의 자 기 적 특성 의 변화 가 일어나 는 화합물 반도체 이 다 .',
#  '스핀트로닉스 는 전자 의 자기 적 이 ㄴ 회전 을 뜻 하 는 스핀 ( spin ) 과 전자 공학 ( electronics ) 의 합성어 로 , 전자 의 전하 뿐 아니 라 업 · 다운스핀 과 같 은 형태 로 스핀 정보 를 이용 하 여 전자 를 구분 하 ㅁ 으로써 전자 의 이동 을 제어 하 는 새롭 ㄴ 개념 의 전자 공학 이 다 .',
#  '본 논문 은 sol - gel 법 을 이용 하 여 II - IV 족 반도체 이 ㄴ 산화아연 ( zinc oxide ) 의 아연 을 전이금속 이 ㄴ 코발트 로 치환 하 고 , 코발트 의 농도 ( x = 0 % , 1 % , 2 % , 3 % , 4 % , 5 % , 10 % , 15 % ) 를 각기 달리 하 여 합성 하 ㄴ 화합물 의 구조 적 및 자기 적 특성 을 조사 하 였 다 .',
#  '본 실험 에서 는 전구 물질 을 zinc acetate dihydrate 와 cobalt acetate tetrahydrate 를 사용 하 여 합성 하 였 다 .',
#  '본 연구 에 사용 되 ㄴ 시약 은 Zinc acetate dihydrate ( Zn ( COOCH 3 ) 2 · 2 H 2 O , Aldrich 99 . 9 % ) , Cobalt acetate tetrahydrate ( Co - ( COOCH 3 ) 2 · 4 H 2 O , Aldrich 99 % ) , Ethanol ( CH 3 CH 2 OH , HPLC 용 Aldrich 99 % ) , Lactic acid ( CH 3 CH ( OH ) COOH , ACS reagent , Aldrich ≥ 85 % ) 을 사용 하 였 다 .',
#  '본 연구 에서 는 Zn 1 - xCoxO ( x = 1 % ~ 15 % ) 묽 은 자성 반도체 물질 을 졸 - 겔 법 ( sol - gel ) 을 이용 하 여 단일상 의 전구체 를 합성 제조 하 였 다 .',
#  'VSM 을 이용 하 여 Zn 1 - xCoxO 의 자 기 적 특성 을 측정 하 였 다 .',
#  '합성 되 ㄴ 시료 는 XRD 를 통하 여 구조 분석 을 수행 하 였 다 .',
#  'XRD 를 통하 여 알아보 ㄴ 변화 는 SEM 을 이용 하 여서 도 확인 하 ㄹ 수 있 다 .',
#  '이 로 인하 여 합성 되 ㄴ Zn 1 - xCoxO 의 구조 는 다결정 을 가지 며 나노크기 의 화합물 이 라는 것 을 확인 하 였 으며 , 이차상 이 아니 ㄴ 단일 상 으로 존재 하 는 울츠자이트 ( wurtzite ) 구조 가 합성 되 ㄴ 것 이 확인 되 었 다 .',
#  '따라서 코발트 의 농도 는 약 5 % 이 ㄹ 때 가장 크 ㄴ 자화 값 을 나타내 ㄴ다 .',
#  '또한 치환 되 ㄴ 코발트 이온 이 가전자 띠 에 위치 하 여 받 게 역할 을 하 여 상대 적 으로 전하 운반체 이 ㄴ 전자 의 농도 를 감소 시키 어 농도 가 증가 하 ㄹ수록 포화 자화 값 이 증가 하 ㅁ 을 확인 하 였 다 .',
#  '이 연구 에서 는 학교 내 신 지필 평가 에 대하 ㄴ 중요도 가 높 아 지 고 있 는 현 시점 에서 , 중학교 1 학년 내신 지필 평가 문항 의 정보 제시 오류 를 조사 하 ㅁ 으로써 교사 에게 지필 평가 문항 의 개발 에 있 어서 유의점 으로 제공 하 여 일선 학교 의 지필 평가 문항 의 질 적 수준 을 향상 시키 는데 기초 자료 로 제시 하 고자 하 ㄴ다 .',
#  '최영기 등 12 은 선다 형 평가 문항 에서 의 오류 분석 을 위하 ㄴ 구체 적 이 ㄴ 방법 과 절차 를 모색 하 기 위하 여 , 오류 분석 을 가능 하 게 하 는 선다 형 평가 문항 작성 원칙 을 제시 하 였 으며 , 실험 평가 를 통하 ㄴ 결과 분석 을 통하 여 학생 들 의 오류 , 학습 상태 등 에 대하 ㄴ 중요 하 ㄴ 정보 들 의 분석 이 가능 하 다고 하 였 다 .',
#  '이용경 13 의 연구 에서 는 중학교 2 학년 수학 과 각 단원 별 학습 목표 에 대하 ㄴ 평가 문항 을 개발 하 ㄴ 뒤 평가 문항 에 대하 ㄴ 학생 들 의 오류 를 분석 하 ㄴ 결과 문제 의 의미 를 제대로 파악 하 지 못하 는 경우 와 전 단계 에서 제대로 학습 이 이루 어 지 지 않 은 경우 , 교사 가 문항 에서 제시 하 ㄴ 용어 의 의미 를 제대로 파악 하 지 못하 는 경우 에 오류 를 발견 하 ㄹ 수 있 다고 보 았 다 .',
#  '교육 평가 의 기능 에 는 수업 목표 달성 도 파악 , 학습 의 진단 과 치료 , 학습 촉진 , 수업 방식 을 개선 하 거나 보충 자료 를 제작 하 는데 이용 하 는 등 여러 가지 기능 이 있 으며 , 특히 지필 평가 의 결과 는 학생 의 선발 을 위하 ㄴ 기초 자료 로서 중요 하 게 사용 되 ㄴ다 . 1 - 3',
#  '이 연구 는 중학교 1 학년 과학 과 지필 평가 문항 중 물질 분야 문항 에 나타나 ㄴ 정보 제시 의 오류 와 오류 유형 별 빈도수 를 조사 · 분석 하 였 다 .',
#  '이 연구 는 특정 도시 의 15 개 중학교 의 학교장 과 과학 교사 들 에게 연구 목적 에 대하 여 설명 하 고 , 학교명 이나 교사명 이 거론 되 지 않 는다는 전제하 에 1 학년 1 학기 지필 평가 문항지 를 제공 받 았 다 .',
#  '예비 조사 의 결과 에 따르 아 분석틀 을 구성 하 여 , 예비 조사 에 사용 되 ㄴ 지필 평가지 를 제외 하 ㄴ 10 개 중학교 의 지필 평가 중 물질 단원 문항 167 개 를 최종 연구 대상 자료 로 하 여 분석 하 였 다 ( Table 1 ) .',
#  '본 연구진 들 과 교사 연구회 의 교사 5 인 이 중학교 1 학년 1 학기 과학 교과 물질 단원 의 지필 평가 문항 을 분석 하 여 , 문항 에 포함 되 ㄴ 정보 에 어떠 하 ㄴ 오류 가 있 는지 를 분석 하 였 다 .',
#  '조사 되 ㄴ 정보 제시 오류 를 유형 화 하 여 정의 하 고 , 그 에 근거 하 여 지필 평가 문항 의 오류 빈도 를 조사 하 였 다 .',
#  '학습자 가 문제 에 대하 ㄴ 의미 를 정확히 파악 하 지 못하 고 추측 에 의하 여 정답 을 선택 하 게 하 ㄹ 가능 성 이 있 으며 문제 를 해결 하 는 과정 에 있 어서 오히려 혼란 을 가중 시키 ㄹ 뿐 만 아니 라 학업 성취 정도 를 정확 하 게 평가 하 는 것 을 불 가능 하 게 만들 ㄹ 수 있 다 .',
#  '교육 과정 내용 을 초월 하 ㄴ 정보 가 지필 평가 문항지 에 제시 되 게 되 면 , 학생 은 선수 학습 을 하 여야 하 ㄴ다고 인식 하 게 되 ㄹ 것 이 고 , 사교육 에 의존 하 게 되 ㄹ 수 있 다 . 결국 교육 과정 의 수준 과 범위 를 넘어서 ㄴ 지필 평가 문항 은 사교육 조장 하 는 원인 으로 작용 하 ㄹ 수 도 있 다 .',
#  '중학교 1 학년 과학 과 물질 분야 문항 에서 조사 되 ㄴ 정보 제시 오류 유형 은 불 충분 하 ㄴ 정보 , 불 필요 하 ㄴ 정보 , 잘못 되 ㄴ 정보 , 교육 과정 내용 을 초월 하 ㄴ 정보 , 불 명확 하 ㄴ 정보 등 의 다섯 가지 로 나타나 았 다 .',
#  '총 167 개 의 문항 중 81 개 의 문항 ( 48 . 50 % ) 에서 정보 제시 오류 가 있 는 것 으로 조사 되 었 다 .',
#  '평가 문항 을 개발 하 ㄹ 때 시간 적 이 ㄴ 여유 를 두 고 문항 을 출제 하 며 , 동교과 , 동교 과목 교사 간 의 교차 검토 를 통하 여서 보다 체계 적 이 고 합리 적 이 ㄴ 문항 개발 을 하 ㄹ 수 있 는 체제 가 이루어지 어야 하 겠 다 .',
#  '2009 년 1 월 에 시행 하 ㄴ 센터 시험 의 이과 시험 39 에서 화학 문항 을 수능 과 관련 하 여 내용 요소 및 행동 영역 에 따르 아 분석 하 고 , 문항 유형 과 특이 사항 을 분석 하 였 으며 한국 수험 생 의 관점 에서 예상 정답 률 을 추정 하 여 수능 의 화학 문항 출제 에 주 는 시사점 을 도출 하 고자 하 였 다 .',
#  '대학 수학 능력 시험 ( 이하 수능 ) 은 대학 신입 생 선발 을 위하 ㄴ 타당 성 제고 , 대학 입시 의 공공 성 을 유지 하 기 위하 ㄴ 최소한 의 조정 기능 유지 , 고차 적 이 ㄴ 사고력 의 평가 강화 , 교육 적 으로 의미 있 는 경쟁 의 유도 등 을 목적 으로 대학 입학 학력고사 대신 에 1994 학년도 부터 도입 되 ㄴ 국가 고사 이 다 .',
#  '따라서 보 ㄴ 연구 에서 는 수능 의 신뢰도 와 타 당 도 제고 를 위하 여 한국 과 마찬가지 로 국가 중심 교육 과정 이 며 국가 수준 에서 이루어지 는 선다 형 시험 유형 을 가지 ㄴ 일본 센터 시험 의 화학 문항 을 분석 하 였 다 .',
#  '일본 의 센터 시험 문항 을 분석 하 기 위하 여 일본 입시 센 터 홈페이지 에 39 게시 되 ㄴ 2009 년 1 월 에 시행 되 ㄴ 검사 의 문항 을 대상 으로 하 였 으며 수능 과 비교 하 기 위하 여서 는 2008 년 11 월 에 시행 되 ㄴ 2009 학년 도 수능 시험 문항 을 사용 하 였 다 .',
#  '센터 시험 의 문항 분석 은 각 과목 별 로 수능 출제 경험 이 있 는 3 명 의 교사 와 1 - 2 명 의 출제 경험 이 있 는 과학 교육 박사 로 구성 되 ㄴ 전문가 들 의 협의 를 통하 여 이루어지 었 다 .',
#  '예상 정답 률 과 함께 센터 시험 문항 의 내용 요소 와 행동 요소 , 센터 시험 의 문항 내용 이 포함 되 ㄴ다고 생각 하 는 한국 의 해당 과목 을 분석 하 였 다 .',
#  '전문가 협의회 에서 교사 들 은 내용 요소 와 행동 요소 , 한국 의 교육 과정 에 해당 하 는 과목 과 특이 하 ㄴ 문항 등 에 대하 여 분석 하 ㄴ 내용 을 논의 하 였 으며 , 논의 후 각 분석 내용 에 대하 여 합의 하 였 다 .',
#  '센터 시험 의 문항 분석 은 교육 과정 내용 요소 , 행동 요소 , 예상 정답 률 등 을 중심 으로 이루어지 ㅁ 을 고려 하 여 교육 과정 에 대하 ㄴ 이해 와 함께 문항 출제 나 검토 에 경험 이 있 는 화학 교사 를 문항 분석 을 위하 ㄴ 전문가 로 위촉 하 였 다 .',
#  '따라서 한국 학생 들 이 문항 을 충분히 사고 하 고 해결 하 ㄹ 수 있 어서 속도 검사 가 아니 ㄴ 역량 검사 가 되 도록 , 문항 수 와 문항 풀이 시간 을 고려 하 ㄴ 출제 를 하 ㄹ 필요 가 있 다 .',
#  '일본 의 경우 최대한 선택 하 ㄹ 수 있 는 조합 이 편성 되 어 이과 과목 4 개 를 고루 공부 하 ㄹ 수 있 도록 선택 이 가능 하 ㄴ 것 에 비하 면 한국 의 경우 는 고등학교 때 부터 이과 4 과목 중 에서 1 - 2 개 의 과목 만 선택 하 여 공부 하 게 하 는 방향 으로 입시 제도 가 바뀌 는 것 에 대하 여서 는 생각 하 여 보 아야 하 ㄹ 문제 이 다 .',
#  '그러나 수능 의 경우 과목 의 유 ․ 불리 문제 와 형식 의 일관 성 때문 에 엄격 하 게 통일 성 을 부여 하 고 있 지만 문항 수 와 배점 , 답 지 수 등 이 다양 화 하 는 것 이 더 좋 은 문항 개발 에 도움 이 되 ㄴ다면 수능 에 도 다소 유연 하 게 적용 하 ㄹ 필요 가 있 다 .',
#  '이러 하 ㄴ 보고서 를 토대 로 차년 도 시험 을 출제 하 ㄹ 때 문제 작성부 에서 적극 반영 하 여 출제 가 이루어지 고 있 는 점 과 , 평가 에 대하 ㄴ 보고서 를 제출 하 면 그 에 해당 하 는 문제 작성 부회 의 적절 하 ㄴ 답변 과 입장 을 밝히 는 보고서 가 보고 되 는 점 은 수능 에서 도 신중 하 게 고려 하 여 보 ㄹ 필요 가 있 다 .',
#  '한국 의 경우 도 상식 가능 하 ㄴ 선 에서 표현 을 완화 하 ㄹ 필요 가 있 다 .',
#  '따라서 보 ㄴ 연구 에서 는 Urea 와 산처리 를 통하 여 제조 되 ㄴ 탄소나노튜브 의 표면 구조 특성 을 관찰 하 고 , 이 에 따르 ㄴ EDLCs 전극 특성 을 확인 하 여 보 고자 하 였 으며 , 또한 탄소나노튜브 표면 에 형성 되 ㄴ 질소 와 산소 관능기 의 원소구성비 에 따르 ㄴ EDLCs 특성 에 관하 여 고찰 하 고자 하 였 다 .',
#  '또한 교류 임피던스 측정 을 위하 여 open circuit potential ( OCP ) 에서 1 Hz 부터 1 MHz 의 주파수 범위 와 amplitude 20 mV 의 조건 하 에서 측정 하 였 다 .',
#  '전기이중 층 커패 시터 ( EDLCs ) 는 전기에너지 를 저장 및 응용 하 는 장치 로서 전극 표면 과 전해질 의 활성 물질 사이 에서 단순 하 ㄴ 이온 들 의 이동 이나 표면 화학 반응 에 의하 ㄴ 전기 화학 적 이 ㄴ 가역 흡착 과정 으로 전 하 를 충전 하 ㄴ다 .',
#  '그 중 에서 탄소 나 노튜브 ( carbon nanotubes ) 는 높 은 전도 성 , 기공 구조 의 제어용 이 및 높 은 화학 적 안정 성 을 갖 고 있 는 물질 로서 , 에너지 저장 장치 분야 ( 이차 전지 , 연료 전지 , 전기 화 학 축 전지 , 및 수소 저장 ) 뿐만 아니 라 다른 분야 에서 도 각광 받 고 있 는 물질 이 다 .',
#  '본 연구 에서 는 산처리 및 Urea 처리 후 열처리 를 통하 여 제조 되 ㄴ 질소 및 산소 관능기 가 화학 적 으로 결합 되 ㄴ 탄소나노튜브 를 제조 하 여 표면 특성 을 살펴보 고 이 에 따르 ㄴ EDLCs 전극 특성 을 고찰 하 였 다 .',
#  '표면 처리 되 ㄴ 탄소 나 노튜브의제조 . 질소 관능기 를 도입 하 기 위하 여 MWNTs 에 Urea 를 1 : 1 의 질량비 로 에탄올 에 넣 고 실온 에서 6 시간 정도 교반 시키 어 잘 분산 시키 ㄴ 다음 에탄올 을 증발 시키 어 진공 오븐 에서 120 ℃ 온도 로 24 시간 건조 시키 었 다 .',
#  '본 연구 에서 사용 하 ㄴ 탄소나노튜브 는 다중 벽타입 ( Multi - walled carbon nanotubes , MWNTs ) 으로서 나노솔루션 ㈜ 에서 구입 하 였 으며 화학 기상 증착법 ( chemical vapor deposition method ) 으로 얻 어 지 었 다 .',
#  'MWNTs 의 기공 구조 . 표면 처리 하 ㄴ MWNTs 의 기공 구조 를 고찰 하 기 위하 여 N 2 기체 흡착량 을 통하 여 등 오 ㄴ 흡착 곡선 을 측정 하 였 으며 , Fig . 1 에 이 를 나타내 었 다 .',
#  "Derjaguin - Landau - Verwey - Overbeek ( DLVO ) theory 에 따르 면 MWNTs 의 입자 는 정전기 적 반 발력 에 의하 여 분산 되 며 , 동등 하 ㄴ 전하 를 띄 는 환경 에서 반데르발스 상호 작용 ( van der Waals ' interaction ) 에 의하 ㄴ 인력 을 극복 하 려는 경향 을 보이 ㄴ다 .",
#  '이 를 통하 여 Urea 처리 를 통하 ㄴ 질소 관능기 의 도입 은 표면 기공 구조 의 손상 을 최소 화 하 며 축전 용량 을 증가 시키 ㄹ 수 있 는 효과 적 이 ㄴ 방법 중 하나 이 ㅁ 을 알 ㄹ 수 있 었 다 .',
#  '이러 하 ㄴ 결과 를 통하 여 , Urea 처리 전 의 산처리 를 통하 여 탄소나노튜브 의 안정 되 ㄴ 분산력 을 이끌 어 내 ㅁ 으로써 , Urea 와 탄소나노튜브 간 의 수월 하 ㄴ 반응 을 유도 하 고 , 더 높 은 질소 관능기 의 도입 을 이끌 어 내 ㄹ 수 있 음 을 확인 하 였 다 .',
#  '많 은 학생 들 은 공유 속성 과 비 공유 속성 을 제대로 구별 하 지 못하 여 속성 들 을 대응 시키 는 과정 에서 다양 하 ㄴ 대응 오류 를 범하 는 것 으로 보고 되 고 있 다 .',
#  '따라서 비유 사용 수업 이 효과 적 으로 이루어지 도록 하 기 위하 여서 는 비유 를 통하 ㄴ 학습 에서 학생 들 의 대응 관계 이해 와 대응 오류 에 영향 을 미치 는 요인 들 을 파악 하 여 , 학생 들 이 올바르 게 대응 관계 를 이해 하 ㄹ 수 있 도록 도와주 ㄹ 필요 가 있 다 .',
#  "이 에 보 ㄴ 연구 에서 는 고등학교 1 학년 과학 교과 의 반응 속도 단원 의 ' 농도 와 반응 속도 ' 개념 에 대하 여 비유 를 사용 하 ㄴ 수업 에서 학생 들 의 과학 성취 도 , 논리 적 사고력 , 시각 적 심상 화 능력 , 비유 추론 능력 등 과 같 은 인지 적 변인 들 및 비유물 에 대하 ㄴ 친숙 도 , 자아 효능감 , 인지 욕구 등 과 같 은 정의 적 변인 에 따르 ㄴ 대응 오류 의 유형 과 그 특성 에 대하 여서 도 조사 하 고 , 이 변인 들 과 대응 관계 이해도 의 관계 를 알아보 고자 하 ㄴ다 .",
#  '이 연구 는 목표 개념 을 학습 하 지 않 은 서울시 에 소재 하 ㄴ 남자 고등학교 의 1 학년 학생 245 명 을 대상 으로 하 였 다 .',
#  '또한 대응 관계 이해도 와 인지 적 ‧ 정의 적 변인 들 간 의 상관관계 를 조사 하 ㄴ 후 , 대응 관계 이해도 를 준거 변인 으로 , 인지 적 ‧ 정의 적 변인 들 을 예언 변인 으로 하 는 단계 적 다중 회귀 분석 ( stepwise multiple regression analysis ) 을 실시 하 여 각 변인 의 설명력 을 조사 하 였 다 .',
#  '각 변인 별 상‧하위 학생 들 간 의 대응 관계 이해 도 점수 와 대응 오류 빈도 의 차이 를 조사 하 기 위하 여 각 검사 점수 의 중앙 값 을 기준 으로 학생 들 을 상위 수준 과 하위 수준 으로 나누 고 , 독립 표집 t 검증 ( independent t - test ) 을 실시 하 였 다 .',
#  '이상 의 결과 는 비유 를 사용 하 ㄴ 학습 에서 학생 들 이 비유물 과 목표 개념 에 포함 되 ㄴ 공유 속성 과 비 공유 속성 들 을 추출 하 여 내 고 이 들 간 의 관계 를 올바르 게 파악 하 는 데 에 는 개별 학생 들 이 지니 고 있 는 인지 적 , 정의 적 변인 이 직 ‧ 간접 적 으로 영향 을 미치 고 있 음 을 보이 어 주 ㄴ다 .',
#  '따라서 추후 학교 급 별 로 과학 교과 의 주요 개념 들 에 대하 ㄴ 다양 하 ㄴ 비유물 을 사용 하 ㄴ 비유 수업 을 실시 하 여 학생 들 의 개별 적 이 ㄴ 특성 과 목표 개념 및 비유물 의 특성 들 간 의 관계 에 대하 여 조사 하 는 연구 들 이 진행 되 ㄹ 필요 가 있 다 .',
#  '따라서 비유 를 개념 학습 에 효과 적 이 ㄴ 도구 로 활용 하 기 위하 여서 는 학습자 의 인지 적 ‧ 정의 적 이 ㄴ 변인 을 고려 하 ㄴ 교수 ‧ 학습 자료 를 개발 하 고 , 학생 들 의 개별 적 이 ㄴ 특성 에 따르 아 대응 오류 를 예방 하 기 위하 ㄴ 방안 을 마련 하 ㄹ 필요 가 있 다 .',
#  '또한 , 이 연구 결과 를 교사 용 지도서 나 자료 집 으로 만들 어 배포 하 고 연수 등 을 통하 여 안내 하 ㅁ 으로써 , 학생 들 의 개별 적 이 ㄴ 인지 적 ‧ 정의 적 변인 에 따르 아 유발 되 ㄹ 수 있 는 대응 오류 를 파악 하 ㄹ 수 있 도록 하 여야 하 ㄹ 것 이 다 .',
#  '본 논문 은 졸 - 겔법 을 이용 하 여 ZnCo 2 ( C 2 O 4 ) 3 · 4 H 2 O 와 NiCo 2 ( C 2 O 4 ) 3 · 4 H 2 O 의 전구체 를 합성 하 였 으며 , 약 350 ℃ 에서 소성 하 여 결정 을 합성 하 였 고 , 이 결정 의 확인 여부 를 X - 선 회절 분석기 ( XRD ) 와 적외선 흡수 분광기 ( IR ) 로 확인 하 였 다 .',
#  '스피 넬 화합물 의 일반 적 이 ㄴ 구조 는 AB 2 O 4 를 나타내 며 여기 에서 A 는 2 개 의 전하 를 갖 는 금속 이 고 , B 는 3 개 의 전하 를 갖 는 금속 이 다 .',
#  '열 적 분석 및 열역학 적 이 ㄴ 특성 을 보 기 위하 여 열중량 분석기 ( TGA ) 를 이용 하 였 으며 , 전구체 의 열 적 분해 로 인하 여 활성 화 에너지 ( Ea ) , 전환인자 ( A ) 및 열역학 적 파라미터 ( △ H φ , △ S φ , △ G φ ) 를 계산 하 였 다 .',
# ...
#  'TT 계통 이란 전원 의 한 점 을 직접접 지 하 고 설비 의 노출 도전 성 부분 을 전 원 계통 의 접지극 과 는 전기 적 으로 독립 하 ㄴ 접지극 에 접지 하 는 접지 계통 이 고 IT 계통 이란 충전부 전체 를 대지 로부터 절연 시키 거나 , 한 점 에 임피 던스 를 삽입 하 여 대지 에 접속 시키 고 전기 기기 의 노출 도전 성 부분 을 단독 또는 일괄 적 으로 접지 하 거나 또는 계통 접지 로 접속 하 는 접지 계통 을 말 하 ㄴ다 .',
#  '감전 보호 의 개념 은 어쩌 ㄹ 수 없 는 기기 의 고장 이나 사람 의 잘못 되 ㄴ 행동 에 대하 여서 도 고려 되 어야 하 므로 모든 경우 를 상정 하 ㄹ 필요 가 있 으며 감전 보호 의 기본 은 인체 가 전기 설비 의 충전부 에 접촉 하 ㄹ 때 인체 를 통하 여 흐르 는 위험 하 ㄴ 전류 를 안전 하 ㄴ 계치 이하 로 억제 하 는 것 이 다 .',
#  '본 논문 에서 는 화재 로 인하 ㄴ 피해 의 현주소 를 알아보 기 위하 여 최근 10 년 동안 화재 발생원 이 ㄴ 중 일정비율 이상 을 차지 하 고 있 는 전기 적 요인 의 누전 · 지락 사고 를 분석 하 였 으며 이런 누전 · 지락 사고 에 대하 여 효율 적 이 며 신뢰 성 이 높 은 저압 전로 를 구축 하 기 위하 여 국제 규격 이 ㄴ IEC 60364 - 4 - 41 을 반영 하 ㄴ KECG 1091 - 2011 의 개정 사항 을 검토 하 였 고 신뢰 성 향상 방안 으로 예방 보전 방식 을 적용 하 였 다 .',
#  '화재 로 인하 ㄴ 피해 의 현주소 를 알아보 기 위하 여 2001 년 1 월 에서 2010 년 12 월 까지 최근 10 년 동안 전국 에서 발생 하 ㄴ 화재 에 대하 ㄴ 발화 요인 별 화재 건수 , 인명 피해 , 재산 피해 를 나타내 면 Figure 1 과 같 다 .',
#  '첫 번 째 로 발화 요인 별 화재 건수 , 인명 피해 , 재산 피해 발생 현황 에서 전기 적 요인 이 각각 23 . 3 % , 13 . 7 % , 26 . 1 % 로 사람 의 부 주의 로 인하 ㄴ 전기 적 요인 에 의하 여 많 은 화재 가 발생 하 ㄴ다는 사실 을 알 ㄹ 수 있 으며 이 중 누전 · 지락 사고 가 4 . 4 % 로 다른 요인 에 비하 여 상대 적 으로 발생 비율 이 높 지 ㄴ 않 지만 장기간 동안 일정 비율 이상 을 차지 하 고 있 으므로 누전 · 지락 사고 를 개선 시키 어 신뢰 성 을 향상 시키 ㄹ 필요 성 을 제시 하 였 다 .',
#  '따라서 , 누전 경보기 에 대하 ㄴ 내용 연수 도 누전 경보기 의 구성 부품 을 고려 하 여 Table 5 에서 나타내 고 있 는 계기 용 변 성기 ( MOF ) 나 CT 의 내용 연수 를 적용 하 는 것 이 바람 직 하 ㄹ 것 이 다 .',
#  '따라서 각 검사표 , 점검표 에 영상 변류기 에 대하 ㄴ 점검 항목 을 추가 하 ㄹ 필요 가 있 으며 점검 및 보고자 를 명확히 하 ㄹ 필요 가 있 다 .',
#  '여기 서 , 누전 · 지락 은 다른 요인 에 비하 여 상대 적 으로 발생 비율 이 높 지 ㄴ 않 지만 장기간 동안 일정 비율 이상 을 차지 하 고 있 는 요인 중 하나 이 므로 누전 · 지락 사고 를 개선 시키 어 신뢰 성 을 향상 시키 ㄹ 필요 가 있 다 .',
#  '따라서 기존 의 누전 경보기 에 비하 여 신뢰 성 도 높 고 실용 성 도 더 뛰어나 ㄴ 디지털 누전 경보기 를 설치 하 여 저 압전 로 의 누전 · 지락 에 대하 ㄴ 신뢰 성 을 향상 시키 ㄹ 필요 가 있 다 .',
#  '세 번 째 로 예방 보전 방식 의 시간 계획 보전방식 으로 누전 경보기 의 영상 변류기 에 대하 ㄴ 정기 정점 제도 와 내용 연수 제도 의 도입 필요 성 을 제시 하 였 고 예방 보전 방식 의 상태 감시 보전방식 으로 실시간 으로 누설 전류 를 감시 하 여 누전 · 지락 사고 에 대하 여 저압전 로 의 신뢰 성 을 향상 시키 ㄹ 수 있 는 누설 전류 통합 감시 장치 와 디지털 누전 경보기 를 제안 하 였 다 .',
#  '따라서 이러 하 ㄴ 문제점 을 해결 하 기 위하 여서 는 변압기 저압 측 중성점 접지선 으로 귀환 되 는 누설 전류 를 실시간 모니터링 하 ㄹ 수 있 는 누설 전류 통합 감시 장치 가 필요 하 다 .',
#  '두 번 째 로 신뢰 성 이 높 은 저압전 로 의 지락 보호 를 구축 하 기 위하 여 IEC 규격 을 부합 화 하 ㄴ KECG 1091 - 2011 개정 사항 을 검토 하 여 전원 자동차단 에 의하 ㄴ 보호 방식 으로 TN , TT , IT 각 접지 방식 별 보호 조건 과 최대차단시간 에 맞 는 시스템 구축 의 필요 성 을 제안 하 였 다 .',
#  '따라서 보 ㄴ 연구 개발 에서 는 국내외 에서 개발 하 ㄴ 피난 시뮬레이션 의 단점 을 보완 하 고 , 앞 으로 의 건축 설계 환 경 에서 실사 용 이 가능 하 ㄴ 화재 피난 시뮬레이션 에 대하 ㄴ 연구 개발 을 진행 하 고자 하 ㄴ다 .',
#  '시뮬레이션 은 2 층 에 73 명 의 에이전트 를 배치 하 ㄴ 후 실행 하 였 으며 , 1 층 에 위치 하 ㄴ 문 을 통하 여 피난 하 는 것 으 로 가정 하 였 다 .',
#  '프로그램 구현 상 황 을 고려 하 여서 엘리베이터 는 삭제 하 였 으며 , 시뮬레이 션 검증 시 에이전트 의 피난 이 정상 적 으로 진행 되 는지 에 대하 ㄴ 관찰 을 용이 하 게 하 기 위하 여서 2 층 에 가구 를 배치 하 여 에이전트 가 장애물 회피 에 대하 ㄴ 검증 을 실시 하 였 다 .',
#  '따라서 보 ㄴ 연구 개발 에서 늘 ㄴ 공간 정보 를 구조 화 하 고 이 를 활용 하 여 유클리드 상 의 평면 공간 이 중첩 되 ㄴ 입체 공간 을 유의미 하 ㄴ 그 러 어 프 구조 로 변환 시키 는 스페이스 토폴 로지 ( Space Topology ) 이 라는 개념 을 연구 하 고 이 를 화재 피나 ㄴ 시뮬레 이션 시스템 에 도입 하 ㄴ다 .',
#  '기본 적 으로 는 파일 입출력 에 관하 ㄴ 기능 과 건축 컴포넌트 데이터 를 파싱 ( Parsing : 문자 열 혹은 Binary Data 에서 원하 는 Data 를 추출 하 여 정리 ) 하 거나 2 D / 3 D 형태 로 가시 화 하 는 기능 등 을 포함 하 ㄴ다 .',
#  '존 노드 와 커넥터 노드 를 이용 하 여 만들 ㄴ 토폴로지 로 서 Figure 7 과 같이 공간 과 출입구 를 고려 하 ㄴ 연결 관 계 토폴로지 이 다 .',
#  '패스 토폴로지 는 Figure 8 과 같이 유클리드 공간 내 에서 에이전트 가 필 드 내 의 두 공간 을 이동 하 ㄹ 경우 에 두 지점 을 최 단거리 로 이동 하 ㄹ 수 있 는 경로 들 의 모든 경우 의 경로 를 나타내 며 보 ㄴ 연구 개발 에서 는 화재 피난 시뮬레이션 시스템 에서 필수 적 으로 필요 하 ㄴ 피난 경로 를 결정 하 는 피난 동선 검토 기능 구현 을 위하 여 패스 토 폴 로지 를 도입 하 였 다 .',
#  '커넥터 토폴로지 는 커넥터 즉 문 을 노드 로 하 는 토 폴 로 지 로서 출입구 간 의 연결 관계 를 나타내 며 , Figure 6 과 같이 커넥터 노드 간 의 연결 은 같 은 존 ( zone ) 에 속 한 커넥터 들 은 에지 ( edge ) 로서 연결 되 며 다음 과 같 은 속성 을 가지 ㄴ다 .',
#  '존이 란 벽체 등 의 물리 적 건축 구성 요소 에 의하 여서 둘 러싸여진 스페이스 의 부분 집합 을 의미 하 며 , Figure 5 와 같이 존 토폴로지 는 공간 간 의 연결 관계 를 나타내 며 다음 과 같 은 특성 을 가지 ㄴ다 .',
#  '공간 에 대하 ㄴ 정보 가 전무 ( 全無 ) 하 ㄴ 상태 이 거나 화재 시 발생 하 는 연기 등 으로 시야 가 제한 적 이 ㄴ 경우 에 이 전트 가 현재 위치 에서 가장 가깝 ㄴ 출구 쪽 으로 진행하 도 록 구현 하 ㄴ다 .',
#  'Intelligent search method 에서 는 현재 머무르 어 있 는 공 간 의 출구 를 통하 여서 피난실 까지 도달 하 ㄹ 수 있 는가아 이러 하 ㄴ 공간 의 출구 중 어느 출구 를 통하 여 피난 하 ㄹ 때 가장 빨리 도달 하 ㄹ 수 있 는가 의 두 가지 정보 를 가지 고 피난 경로 를 선택 하 는 피난경로 탐색 방법 이 다 .',
#  '또한 , 스페이스 토 폴로지 를 존 토폴로지 ( zone topology ) , 커넥터 토폴로지 ( connector topology ) , 존 - 커 넥터 토폴 로 지 ( zone - connector topology ) , 패스 토폴로 지 ( path topology ) 등 서브 토폴로 지 ( Sub topology ) 로 세 부 구현 하 여 화재 피난 시뮬레이션 시스템 사용자 가 필 요 에 따르 아 다양 하 게 활용 하 ㄹ 수 있 도록 하 였 다 .',
#  '각각 의 에이전트 마다 패스 토폴로지 를 실시간 계산 하 기 때문 에 탈출구 까지 매순간 의 상황 을 인지 하 며 지 ㄴ 행 방향 을 계산 하 는 알고리즘 으로 , Omniscience search method 는 다음 과 같 은 순서 로 구현 되 ㄴ다 .',
#  '건축물 도 면 저작 에 주로 활용 하 는 dxf ( 2 차원 공간 정보 ) 를 활용 하 여 객체 기반 의 공간 정보 를 가지 는 3 차원 공간 을 저작 하 는 방법 을 검토 하 여 객 체 가 ㄴ 상호 인식 을 통하 여 건축물 내 의 각 공간 이 위계 구조 ( Hierarchy Tree ) 를 가지 는 방법 을 적용 하 였 으며 , 플랫폼 - 모듈 구조 방식 을 활용 하 ㄴ 건축물 의 특성 및 피 난자 의 행태 반영 이 용이 하 ㄴ 엔진 을 개발 하 여 플랫폼으 로 설정 하 고 , 화재 피난 시뮬레이션 에서 필요 로 하 는 다 양한 세부 모듈 을 플랫폼 에 결합 하 는 방식 을 제시 하 고자 하 ㄴ다 .',
#  '본 연구 에서 는 화재 피난 시뮬 레이션 에서 적용 되 ㄹ 휴먼 모델 및 각 에이전트 모델 의 이동 행태 를 반영 하 ㄹ 수 있 도록 에이전트 보행 , 피난구 역 까지 에이전트 의 피난 루트 를 탐색 하 는 피난 모듈 과 더불 어 화재 상황 을 예측 고려 하 기 위하 ㄴ FDS 연동 을 위 하 여 화재 및 연기데이터 를 가시 화 모듈 을 포함 하 ㄴ다 .',
#  '또한 , 화재 연소 시뮬레이션 결과 와 피난 시뮬레이 션 을 연동 하 여서 시뮬레이션 을 수행 하 는 결과 에서 화재 온도 데이터 와 연기 데이터 를 프로그램 에서 가시 화 하 이 었 다 .',
#  '해석 대상 건물 은 2 층 규모 의 노인 복지 시설 ( 가 로 40 m × 세로 20 m ) 을 대상 으로 실시 하 였 으며 , 해당 건물 은 1 개 소 의 계단 으로 구성 되 어 있 다 .',
#  '건축물 에 대하 ㄴ 화재 연소 시뮬레이션 은 미국 기술 표 준국 ( NIST ) 에서 개발 / 배포 하 는 FDS ( Fire Dynamic Simulator ) 와 연동 을 통하 여 구현 하 도록 하 였 으며 , 그 방 법 은 시뮬레이션 을 실행 하 ㄹ 공간 정보 를 화재 피나 ㄴ 시뮬 레이션 시스템 에 불러들이 ㄴ 후 FDS 의 입력데이터 로 Export 하 여 외부 의 Command Line 에서 FDS 를 실행 하 며 , 이후 FDS 를 실행 하 ㄴ 결과 파일 을 검토 분식 및 가 아 시화 하 ㅁ 으로써 화재 피난 시뮬레이션 을 구현 하 였 다 .',
#  '이러 하 ㄴ 에이전트 보행 모델 은 일반 적 으로 해석 의 가 ㄴ 소화 를 위하 여 분석 방법 을 CA ( Cellular Automata ) 기법으 로 주로 개발 되 고 있 으며 , 이러 하 ㄴ CA 기법 은 주어지 ㄴ 공 간 을 일정 하 ㄴ 격자 로 표현 하 는 방식 으로 공간 을 이산 화 ( discrete ) 하 여 , 에이전트 가 셀 에서 셀로 이동 하 는 방식 으로 움직이 ㄹ 수 있 도록 구현 하 ㄴ다',
#  '또한 , 건축물 에서 발생 하 는 화재 상황 재현 을 위하 여서 미국 기술 표준국 ( NIST ) 에서 개발 배포 하 는 FDS ( Fire Dynamic Simulator ) 와 데이터 입출력 연동 을 통하 여 건축물 의 화재 연소 에 따르 ㄴ 피난 시뮬레이션 을 구현 하 도록 하 였 다 .',
#  '( 2 ) 기존 의 피난 해석 에서 에이전트 의 성별 , 나이 , 키 , 체중 등 의 물리 적 능력 을 통하 여 피난 알고리즘 을 구현 한 반면 , 해석 알고리즘 을 다양 하 게 반영 하 여 , 각각 의 에이전트 의 특성 을 충분히 반영 하 ㄹ 수 있 도록 구현 하 ㄹ 수 있 었 다 .',
#  '( 1 ) 한국 형 에이전트 를 통하 여 한국인 의 외형 적 특성 반영 을 통하 여 한국 에서 발생 하 ㄹ 수 있 는 여러 위험 상황 에 대하 ㄴ 피난 결과 에 대하 여 정확 도 및 신뢰도 를 확보 하 ㄹ 수 있 었 다 .',
#  '( 3 ) 기존 에 주로 사용 하 고 있 는 CA ( Cellular Automata ) 기반 의 보행 모델 이 셀 에서 셀로 이동 하 는 방식 으로 인간 의 보행 행태 가 Cell 에 구애 받 는 단점 을 보완 하 기 위하 여 Continuous Space Model 의 보행 모듈 을 통하 ㄴ 벡 터 방식 을 사용 하 여 세 ㄹ 기반 에 비하 여 공간 내 에서 벡터 를 구애 받 지 않 고 다양 하 ㄴ 형태 로 그리 어 피난 루트 를 서 ㄹ 정하 ㄹ 수 있 었 다 .',
#  '( 4 ) 3 차원 객체 기반 의 Modeler 를 활용 하 ㅁ 으로써 직 관적 이 ㄴ 공간 구축 및 검토 가 가능 하 므로 , 비 숙련자 도 비교 적 쉽 게 사용 및 평가 가 가능 하 ㅁ 을 확인 하 ㄹ 수 있 었 다 .',
#  '또한 , 에이전트 의 주관 적 반응 및 심리 상태 미반영 , 화재 시 건축물 의 재질 속성 을 반영 하 지 못하 ㄴ 한계점 을 지니 고 있 으므로 후속 연구 를 통하 여 이 에 대하 ㄴ 보완 이 필요 하 다 .',
#  '본 연구 에서 는 ASTM E 659 ( Koehler 사 ) 장치 5 , 6 , 8 ) 를 사용 하 여 n - Butanol 과 n - Decane 의 혼합물 에 대하 여 자연 발화 온도 를 측정 하 였 다 .',
#  '자연 발화 ( Autoignition 혹은 Spontaneous Ignition ) 는 가연 성 혼합기체 에 열 등 의 형태 로 에너지 가 주어지 었 을 때 스스로 타 기 시작 하 는 산화 현상 으로 , 주위 로부터 충분 하 ㄴ 에너지 를 받 아서 스스로 점화 하 ㄹ 수 있 는 최저 온도 를 최소자연발 화 온도 ( AIT : Autoignition Temperature ) 이 라고 하 ㄴ다 .',
#  'n - Butanol 과 n - Decane 계 를 구성 하 는 순수 성 분 이 ㄴ n - Butanol 과 n - Decane 계 의 최소자연발 화 온도 를 측정 하 여 문헌 값 들 과 비교 고찰 하 였 다 .',
#  '본 실험 에 사용 되 ㄴ 시약 은 n - Butanol 은 Junsei ( Japan ) , n - Decane 은 Lancaster ( USA ) 사로 서 순도 는 각각 99 % 의 시약 을 사용 하 였 으며 , 혼합물 의 발화온도 측정 은 순수 물질 을 각 각 다른 몰비 ( Mole Fraction ) 로 혼합 하 여 실험 하 였 다 .',
#  '본 실험 에서 는 액체 화학 물질 의 자연 발화점 측정 장치 로서 ASTM E 659 ( Koehler 사 ) 를 사용 하 여 자연 발화 온도 를 측정 하 였 으며 , 장치 는 크 게 Furnace , Temperature Controller , Thermocouple , Test Flask , Hypodermic Syringe , Mirror , Air Gun 으로 구성 되 어 있 다 .',
#  '본 연구 에서 는 Frank - Kamenetskii 이론 을 도입 하 여 발화온도 와 발 화 지연 시간 의 간략히 설명 하 고자 하 ㄴ다 .',
#  '이성 분계 를 구성 하 는 2 개 의 순수 물질 의 최소자연발 화 온도 를 측정 하 ㄴ 결과 , n - Butanol 은 340 oC 그리고 n - Decane 은 212 oC 로 측정 되 었 다 .',
#  '2 ) n - Butanol + n - decane 계 에서 최소자연발 화 온도 를 측정 하 ㄴ 결과 , n - Butanol ( 0 . 3 ) + n - decane ( 0 . 7 ) 에서 는 233 oC , n - Butanol ( 0 . 5 ) + n - decane ( 0 . 5 ) 에서 는 247 oC , n - Butanol ( 0 . 7 ) + n - decane ( 0 . 3 ) 에서 는 267 oC , n - Butanol ( 0 . 9 ) + n - decane ( 0 . 1 ) 에서 는 300 oC 로 나타나 았 다 .',
#  '본 연구 에서 얻 은 측정 값 을 분석 하 ㄴ 결과 조성 변화 에 따르 ㄴ 최소자연발 화 온도 가 증가 하 는 경향 을 보이 고 있 다 .',
#  '그러나 기존 의 GC 는 장치 가 크 고 무겁 ㄹ 뿐 만 아니 라 전력 을 많이 소모 하 므로 휴대 가 어렵 어서 현장 적용 이 어렵 다 .',
#  '가장 보편 적 으로 사용 되 는 불꽃 이 온화 ( FID ) 와 열전도도 ( TCD ) 검출기 를 이용 하 여 다양 하 ㄴ 컬럼 과 혼합물 시료 에 대하 ㄴ 분리능 과 검출 한도 를 측정 하 였 다 .',
#  'Tedlar 백 ( SKC , 232 - 05 ) 에 일정 부피 의 오염 되 지 않 은 공기 를 대 용량 주사기 ( Restek , 500 MAR - LL - GT , 500 mL ) 를 이용 하 여 주입 하 고 , 액체 상태 의 휘발 성 유기 화 합물 을 성분 별 로 마이크 로 주사기 를 이용 하 여 Tedlar 백 에 주입 시키 어 ppm 또는 ppb 농도 의 표준 시료 를 제조 하 였 다 .',
#  '다양 하 ㄴ VOC 류 혼합 기체 에 대하 ㄴ 분리 능력 을 검증 하 기 위하 여 26 가지 의 극성 및 비극 성 유기 화합물 을 포함 하 ㄴ Volatiles MegaMix ( EPA Method 624 , Restek # 30497 ) 샘플 을 분석 하 여 상용 GC 의 결과 와 비교 하 였 다 ( Fig . 4 ) .',
#  '소형 GC 모듈 에 의하 ㄴ 정량 분석 의 능력 을 확인 하 기 위하 여 CH 4 , CO , CO 2 기체 의 농도 에 따르 ㄴ GC 크 로 마토그램 의 피크 면적 을 측정 하 였 다 .',
#  'Fig . 5 b 는 H 2 , CH 4 , CO , CO 2 가 각각 2 % 씩 He 에 포함 되 어 있 는 혼합 기체 를 3 m 길이 의 1 / 8 인치 스테인리스 관 에 Carboxen 1000 ( Supelco , 60 / 80 mesh ) 을 충진 하 고 60 ℃ 로 일정 하 게 유지 하 면서 열전도 도 검출기 로 분석 하 ㄴ 크 로 마토그램 이 다',
#  'Fig . 6 은 H 2 , CH 4 , N 2 , O 2 , CO , CO 2 기체 가 각각 2 % 씩 He 에 포함 되 어 있 는 혼합 기체 를 Carbosieve S - II 충진 컬럼 으로 분리 하 고 열전도 도 검출기 로 분석 하 ㄴ 결과 이 다 .',
#  '다양 하 ㄴ 고정상 ( Molesieve 13 X , Carbosieve S - II , Carboxen 1000 ) 의 컬럼 모듈 을 제작 하 여 H 2 , CH 4 , N 2 , O 2 , CO , CO 2 등 의 가볍 ㄴ 기체 혼합물 에 대하 ㄴ 분석 실험 을 수행 하 였 으며 우수 하 ㄴ 직진 성 , 넓 은 농도 범위 , 낮 은 측정 하한치 를 확인 하 였 다 .',
#  '자체 개발 하 ㄴ 컬럼 모듈의 특성 을 상용 의 GC 와 비교 하 기 위하 여 대표 적 이 ㄴ 휘발 성 유기 혼합물 에 대하 ㄴ 분석 을 수행 하 였 다 .',
#  '본 연구 에서 는 분리 컬럼 과 GC 부품 들 을 소형 화 하 고 감도 및 분해능 을 최적화 하 ㅁ 으로써 현장 에서 10 분 이내 에 대 기 유해물질 의 신속 하 ㄴ 정량 분석 이 가능 하 ㄴ 휴대 형 GC 모듈 을 개발 하 였 다 .',
#  '따라서 앞 에서 수행 하 ㄴ 세 가지 고정상 Molesieve 13 X , Carbosieve S - II , Carboxen 1000 중 에서 가볍 ㄴ 기체 혼합물 의 분리 능력 과 분석 시간 을 고려 하 여 보 면 Carbosieve S - II 로 채우 ㄴ 충진 컬럼 이 가장 우수 하 ㄴ 성능 을 나타내 ㅁ 을 알 ㄹ 수 있 다 .',
#  '특히 Molesieve 13 X 충진 컬럼 에 비하 여 질소 와 산소 의 분리 가 잘 이루어지 지 않 는 다 는 사실 은 주목 하 ㄹ 만 하 다 .',
#  '대표 적 이 ㄴ 휘발 성 유기 화 합물 ( 벤젠 , 톨루엔 , o - 크 실 렌 ) 을 사용 하 여 자체 개발 하 ㄴ 소형 GC 모듈 과 상용 GC 의 분리능 을 비교 하 였 고 26 가지 휘발 성 혼합물 을 분석 하 ㅁ 으로써 자체 제작 하 ㄴ 소형 GC 모듈 이 대기 환경 시료 중 에 공존 하 는 대부분 의 혼합물 을 분리 하 여 검출 하 는데 효과 적 으로 사용 되 ㄹ 수 있 음 을 입증 하 였 다 .',
#  '따라서 소형 GC 모듈 은 현장 분석 이 가능 하 고 분석 시간 이 짧 아 오염원 의 발생 이나 배출 정보 를 보다 빨리 알 ㄹ 수 있 어 오염원 의 진원지 파악 을 통하 ㄴ 빠르 ㄴ 대처 로 오염 을 최소 화 시키 ㄹ 수 있 으리라 기대 되 ㄴ다 .',
#  '따라서 상기 검출 방법 들 이 B 형 간염 바이러스 의 검출 에 유용 하 게 적용 하 ㄹ 수 있 음 을 보이 고자 하 ㄴ다 .',
#  '등온증폭 방법 ( loop - mediated isothermal amplification , LAMP ) 은 2000 년 Notomi 에 의하 여 알리 어 지 ㄴ 증폭 방법 으로 기존 의 PCR 법 과 유사 하 지만 PCR 이나 real - time PCR 반응 시 에 DNA 변성 ( denaturation ) , 프라이머 의 접합 ( annealing ) , 중합 효소 의 신장 ( extension ) 에 필요 하 였 던 온도 변화 가 필요 없이 60 ℃ 의 한 온도 에서 증폭 반응 이 가능 하 ㄴ 검출 방법 으로써 기존 검출 방법 보다 검출 시간 을 획기적 으로 단축 시키 ㄹ 수 있 는 검출 방법 이 다 .',
#  '변성 고 성능 액체크 로 마 토 그래피 ( Denaturing high performance liquid chromatography , DHPLC ) 는 DNA 나 RNA 와 같 은 핵산 분석 에 특화 되 ㄴ 액체크 로 마토그래피 기기 장치 로써 , 핵산 의 정량 분석 이나 DNA 상 의 염기 의 결실 , 삽입 또는 치환 에 의하 ㄴ 돌연변이 를 검출 하 는 목적 으로 사용 되 고 있 다 .',
#  '임상 시료 는 단국대 학교 병원 에서 확인 되 ㄴ B 형 간염 환자 33 명 에게서 수집 하 여 보 ㄴ 실험 에 사용 하 였 다 .',
#  '본 실험 에서 는 표준 B 형 간염 바이러스 로 ATCC 45020 D 를 사용 하 였 다 .',
#  '따라서 보 ㄴ 논문 에서 는 DHPLC 를 이용 하 ㄴ 검출법 과 등온증폭반응법 의 임상 적용 가능 성 을 판단 하 기 위하 여 , 기존 임상 에서 적용 하 고 있 는 B 형 간염 바이러스 의 검출 방법 중 real - time PCR 과 DHPLC 그리고 등온증폭 반응법 을 비교 분석 하 였 다 .',
#  '본 연구 의 결과 , UV 검출기 를 사용 하 ㄴ DHPLC 분석법 과 형광 검출기 를 사용 하 ㄴ DHPLC 의 결과 사이 에 는 두드러지 ㄴ 민감도 의 차이 를 보이 지 않 았 다 .',
#  '따라서 , 위 두 검출 방법 이 임상 에서 B 형 간염 바이러스 의 검출 에 유용 하 게 사용 되 ㄹ 수 있 음 을 밝히 었 다 .',
#  'DHPLC 법과 등온증폭반응법 의 결과 ( Fig . 2 , 3 ) 를 보 았 을 때 , 임상 에서 B 형 간염 바이러스 의 감염 을 판단 하 는 기준 치 이 ㄴ 105 copy / ml 을 충분히 검출 하 ㄹ 수 있 는 검사 방법 이 ㅁ 을 알 ㄹ 수 있 다 .',
#  '또한 , 등온증폭반응법 의 검출 결과 는 DHPLC 법 과 동일 하 ㄴ 민감도 를 보이 었 다 .',
#  '따라서 차후 연구 에서 는 DHPLC 를 이용 하 ㄴ 항바이러스제 내성 B 형 간염 바이러스 의 검출법 에 관하 ㄴ 연구 를 진행 하 ㄹ 예정 이 다 .',
#  '이 에 보 ㄴ 연구 에서 는 함수율 을 증가 시키 지 않 으면서 도 습윤 성 을 향상 시키 ㄹ 수 있 는 glycerol dimethacrylate 를 사용 하 여 고습윤 성 콘택트렌즈 재료 를 중합 하 고 기본 적 이 ㄴ 물성 과 습윤 성 을 평가 하 였 다 .',
#  '전체 시스템 은 General Incubator 에 위치 하 여 35 ℃± 0 . 5 ℃ 의 온도 를 유지 하 였 으며 , 실험 에 사용 되 ㄴ 콘택트렌즈 는 최소 검사 24 시간 전 에 표준 식염수 용액 에 보관 하 고 검사 온도 에서 최소한 2 시간 동안 평형 을 이루 게 하 였 다 .',
#  '본 연구 는 콘택트렌즈 재질 로 널리 사용 되 는 친수 성 monomer 와 glycerol dimethacrylate 를 공중합 하 여 콘택트 렌즈 를 제조 하 고 제조 되 ㄴ 콘택트렌즈 의 함수율 , 굴절 률 , 광투 과율 , 산소 전달 율 등 의 기본 적 이 ㄴ 물성 을 측정 하 였 으며 , 3 ( trimethoxysilyl ) propyl methacrylate 를 첨가 하 ㄴ 조합 과 함께 접촉각 을 측정 하 여 습 윤 성 을 비교 하 였 다 .',
#  '일반 적 이 ㄴ 콘택트렌즈 재료 이 ㄴ HEMA ( 2 - Hydroxyethylmethacrylate ) 와 MA ( methacrylic acid ) , MMA ( methyl methacrylate ) 는 Aldrich 사 의 특급 시약 을 사용 하 였 다 .',
#  '개시 제 로 사용 되 ㄴ AIBN ( 2 , 2 - azobisisobutyronitrile ) 은 JUNSEI 사 에서 , 교차 결합제 이 ㄴ EGDMA ( etyleneglycol dimethacrylate ) 역시 Aldrich 에서 구입 하 여 사용 하 였 다 .',
#  '실험 을 위하 여 첨가 되 ㄴ 각각 의 재료 이 ㄴ GDMA ( glycerol dimethacrylate ) 와 3 MPM [ 3 ( trimethoxysilyl ) propyl methacrylate ] 도 역시 Aldrich 의 특급 시약 을 사용 하 였 다 .',
#  '습윤 성 측정 은 접촉각 을 측정 하 여 평가 하 였 으며 , S . E . O . 사 의 Phoenix - Mini 접촉각 측정기 를 사용 하 였 다 .',
#  '함수율 측정 은 ISO 18369 - 4 : 2006 ( Ophthalmic optic contact lenses - part 4 : Physicochemical properties of contact lens materials ) 을 사용 하 여 gravimetric method 로 측정 하 였 으며 , 제조 되 ㄴ 콘택트렌즈 를 24 시 간 동안 식염수 ( 0 . 9 % 염화나트륨 용액 ) 에 swelling 시키 ㄴ 후 wet blotting 방법 을 사용 하 여 swelling 되 ㄴ sample 의 무게 를 측정 하 였 고 500 ~ 650 W 정도 세기 로 건조 하 ㄴ 후 실온 에서 30 분 유지 하 여 건조 되 ㄴ 무게 를 측정 하 였 다 .',
#  '광투 과율 은 TM - 2 ( TOPCON , Japan ) 를 사용 하 였 으며 UV - B , UV - A 그리고 가시광선 영역 을 각각 측정 하 고 백분율 로 표시 하 여 나타내 었 다 .',
#  '본 실험 에서 사용 되 ㄴ 콘택트렌즈 제조 방법 으로 는 캐스트 몰드법 ( cast mould ) 을 사용 하 여 렌즈 를 제조 하 였 으며 , 일정 하 ㄴ 비율 로 배합 되 ㄴ monomer 를 콘택트렌즈 몰드 에 주입 시키 고 80 ℃ 에서 2 시간 열중합 하 였 다 .',
#  '본 실험 결과 를 통하 여 glycerol dimethacrylate 를 첨가 하 ㄴ 콘택트렌즈 재질 의 경우 , 기본 적 이 ㄴ 콘택트렌즈 의 물성 을 만족 하 ㅁ 과 동시 에 함수율 을 증가 시키 지 않 고 습윤 성 을 증가 시키 ㄹ 수 있 는 물질 로 습윤 성 콘택트렌즈 소재 로 그 활용 성 이 매우 크 ㄹ 것 으로 기대 되 ㄴ다 .',
#  '그 결과 , GDMA 를 넣 은 조합 의 경우 , 함수 율 은 22 ~ 32 % 의 범위 로 측정 되 었 으며 , glycerol dimethacrylate 의 비율 이 증가 하 ㄹ수록 함수 율 이 감소 하 는 것 으로 나타나 았 다 .',
#  '굴절 률 은 1 . 442 ~ 1 . 463 의 범위 로 나타나 았 으며 , GDMA 의 비율 이 증가 하 ㄹ수록 굴절 률 이 증가 하 는 경향 을 보이 었 다 .',
#  '접촉각 을 측정 하 ㄴ 결과 , 56 ~ 65 ° 의 범위 를 나타내 었 으며 , 함수율 이 감소 하 ㅁ 에 도 GDMA 의 비율 이 증가 하 ㄹ수록 접촉각 은 감소 하 여 습윤 성 이 증가 하 는 것 으로 나타나 았 다 .',
#  '가시 광선 투과도 는 모든 조합 에서 약 90 % 의 투과도 를 나타내 었 으며 , 자외선 차단 능력 은 없 는 것 으로 나타나 았 다 .',
#  '전체 적 으로 GDMA 의 비율 이 증가 하 ㄹ수록 굴절 률 은 증가 하 는 것 으로 나타나 았 다 .',
#  '또한 G - 5 의 평균 함수 율 은 31 . 15 % , G - 10 27 . 90 % , G - 15 24 . 35 % , 그리고 G - 20 의 평균 함수 율 은 22 . 13 % 로 나타나 아 GDMA 의 비율 이 증가 하 ㄹ수록 함수 율 은 점차 감소 하 는 경향 을 나타내 었 다 .',
#  '그러나 GDMA 의 비율 이 증가 하 ㄹ수록 표면 적 으로 나타나 는 렌즈 의 유연 성 은 다소 감소 하 는 것 으로 나타나 았 다 .',
#  '전체 적 으로 GDMA 의 비율 이 증가 하 ㄹ수록 접촉각 은 감소 하 는 것 으로 나타나 았 다 .',
#  '본 실험 결과 를 통하 여 glycerol dimethacrylate 를 첨가 하 ㄴ 콘택트렌즈 재질 의 경우 , 기본 적 이 ㄴ 콘택트렌즈 의 물성 을 만족 하 ㅁ 과 동시 에 함수율 을 증가 시키 지 않 고 습윤 성 을 증가 시키 ㄹ 수 있 는 물질 로 습윤 성 콘택트렌즈 소재 로 그 활용 성 이 매우 크 ㄹ 것 으로 기대 되 ㄴ다 .',
#  "이 연구 의 연구 문제 로 학생 들 은 이전 에 접하 여 보 지 못하 ㄴ 문제 를 새롭 고 적절 하 게 해결 하 는 과정 에서 조 별 활동 을 통하 여 지금 까지 많이 경험 하 여 보 지 못하 였 던 ' 발산 적 사고 ' 를 활용 하 게 하 는 활동 이나 ' 수렴 적 사고 ' 를 활용 하 게 하 는 활동 들 을 자주 경험 하 게 하 면 그 들 은 문제 를 창의 적 으로 해결 하 게 하 는 능력 이 신장 되 ㄹ 것 이 라고 설정 하 였 다 .",
#  '이 연구 에서 는 창의 적 사고력 은 협의 의 측면 으로 발산 적 사고력 이 고 , 과학 과 에서 의 문제 해결력 은 탐구 능력 이 며 수렴 적 사고 이 ㄴ 비판 적 사고력 이 라고 전제 하 여 진행 하 였 다 .',
#  "창의 성 을 협의 적 으로 정의 하 면 ' 발산 적 사고 ' 또는 ' 확산 적 사고 ' 라고 하 ㄴ다 .",
#  '그 적용 효과 로 창의 적 사고력 의 변화 , 문제 해결력 의 변화 , 창의 적 문제 해결력 의 변화 , 그리고 여러 가지 사고력 에 대하 ㄴ 인식 을 알아보 았 다 .',
#  '이 와 같 은 과정 이 되 도록 개발 하 ㄴ 창의 적 문제 해결력 지향 탐구 수업 모형 에 의하 ㄴ 수업 전략 을 사범 대학 학생 들 에게 1 학기 동안 적용 하 였 다 .',
#  '이 연구 의 대상 은 고등학교 를 졸업 하 여 대학 에 갓 입학 하 ㄴ 1 학년 학생 으로 서울시 소재 대학교 사범 대학 과학 교육 과 의 96 명 이 다 .',
#  '이 연구 에서 관찰 되 는 학생 들 의 창의 적 문제 해결력 의 변화 를 알아보 기 위하 여 실시 하 ㄴ 사전 · 사후 검사 에 따르 ㄴ 모든 통계 처리 로 SPSS 12 . 0 프로그램 을 사용 하 였 다 .',
#  "' 창의 적 문제 해결력 검사지 ' 는 9 실험 반 과 통제반 학생 모두 에게 사전 · 사후 검사 도구 로 사용 하 였 다 .",
#  "이 연구 에서 개발 하 ㄴ ' 사고력 에 대하 ㄴ 인식 검사지 ' 는 실험 반 과 통제반 학생 모두 에게 사전 에 만 실시 하 였 다 .",
#  ...]

# %%
'''df = pd.read_csv("refined_data_pre.tsv", delimiter='\t', names=['tag', 'sentence'])
data = df['tag'] == '후속연구'
df = df[data]
df = df.values
df[:,1]'''

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import csv
import numpy as np

# %%
df = pd.read_csv("refined_data_pre.tsv", delimiter='\t', names=['tag', 'sentence'])

LabelData = df['tag']
TextData = df['sentence']

# %%
api = KhaiiiApi()

def pos_text(Text_train):
    corpus = []
    for sent in Text_train:
        pos_tagged = ''
        for word in api.analyze(sent):
            for morph in word.morphs:
                pos_tagged += morph.lex + ' '
        corpus.append(pos_tagged.strip())
    return corpus

TextData = pos_text(TextData)

# %%
x_text = TextData
y = LabelData
TextData = np.array(TextData)    
s = np.arange(TextData.shape[0])
np.random.shuffle(s)

TextData = TextData[s]
#print ("셔플 한 뒤의 문장 배열: ", TextData)
LabelData = LabelData[s]
#print ("셔플 한 뒤의 라벨 배열: ", LabelData) 

x_train, x_test = train_test_split(TextData, test_size=0.2, shuffle=False)
y_train, y_test = train_test_split(LabelData, test_size=0.2, shuffle=False)

        
    
# Write to TSV file
with open('train_token.tsv', 'wt', newline='', encoding='utf-8-sig') as f:
    print('Write train data to {} ...'.format('train.tsv'))
    writer = csv.writer(f, delimiter='\t')
    writer.writerows(zip(y_train, x_train))
with open('test_token.tsv', 'w', newline='', encoding='utf-8-sig') as f:
    print('Write test data to {} ...'.format('test.tsv'))
    writer = csv.writer(f, delimiter='\t')
    writer.writerows(zip(y_test, x_test))
# Out:
# Write train data to train.tsv ...
# Write test data to test.tsv ...
