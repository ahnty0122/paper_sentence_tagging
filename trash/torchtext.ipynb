print("|train|=%d" % len(loaders.train_loader.dataset))
print("|valid|=%d" % len(loaders.valid_loader.dataset))
# Out:
# |train|=40571
# |valid|=10143

# %%
print("|vocab|=%d" % len(loaders.text.vocab))
print("|label|=%d" % len(loaders.label.vocab))
# Out:
# |vocab|=14813
# |label|=9

# %% [markdown]
# ### Get mini-batch tensors

# %%
data = next(iter(loaders.train_loader))

print(data.text.shape)
print(data.label.shape)
# Out:
# torch.Size([256, 40])
# torch.Size([256])

# %% [markdown]
# ### Use vocab

# %%
dir(loaders.text.vocab)
# Out:
# ['UNK',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_default_unk_index',
#  'extend',
#  'freqs',
#  'itos',
#  'load_vectors',
#  'set_vectors',
#  'stoi',
#  'unk_index',
#  'vectors']

# %%
loaders.text.vocab.stoi['배송']
# Out:
# 3966

# %%
loaders.text.vocab.itos[48]
# Out:
# '들'

# %% [markdown]
# #### Check most frequent words

# %%
for i in range(50):
    word = loaders.text.vocab.itos[i]
    print('%5d: %s\t%d' % (i, word, loaders.text.vocab.freqs[word]))
# Out:
#     0: <unk>	0
#     1: <pad>	0
#     2: 하	107540
#     3: ㄴ	60174
#     4: 의	58368
#     5: 을	57010
#     6: .	54313
#     7: ,	53979
#     8: 는	47794
#     9: 이	42960
#    10: 에	37674
#    11: 를	36566
#    12: 다	32777
#    13: 여	29939
#    14: 되	24246
#    15: 으로	23037
#    16: 에서	22481
#    17: )	22334
#    18: 였	21932
#    19: (	21198
#    20: 은	19045
#    21: 적	18410
#    22: 있	16404
#    23: 고	14993
#    24: 가	14560
#    25: 연구	14535
#    26: 과	14237
#    27: ㄹ	13129
#    28: 로	12289
#    29: 와	10250
#    30: 것	9632
#    31: 성	9502
#    32: -	9087
#    33: 수	9057
#    34: 위하	8918
#    35: 었	8848
#    36: 분석	8600
#    37: ㄴ다	8574
#    38: 및	8479
#    39: 기	8089
#    40: 대하	7882
#    41: 본	7614
#    42: 사용	6907
#    43: 어	6823
#    44: 1	6585
#    45: 결과	6571
#    46: 2	6494
#    47: 으며	5953
#    48: 들	5904
#    49: 이용	5655

# %% [markdown]
# #### Restore text from tensor

# %%
print(data.text[-1])
# Out:
# tensor([ 763,    4,   79,    8,  577,  191,   16, 2662,    0,   10,   69,  205,
#          152,    0,   24,   72,   54,   74,   61,   47,    7,  577,  191,   29,
#         6069,  191,   16,    8, 8447,    2,    3,  363,   11,   97,   35,   12,
#            6,    1], device='cuda:0')

# %%
x = data.text[-1]
line = []
for x_i in x:
    line += [loaders.text.vocab.itos[x_i]]
    
print(' '.join(line))
# Out:
# 전류 의 경우 는 정상 상태 에서 날개 <unk> 에 5 ~ 8 <unk> 가 높 게 나타나 았 으며 , 정상 상태 와 구속 상태 에서 는 확연 하 ㄴ 차 를 보이 었 다 . <pad>
